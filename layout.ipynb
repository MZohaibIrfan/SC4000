# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import torch
from torch import Tensor
from torch import nn
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from scipy.stats import kendalltau
from torch.nn.utils.rnn import pad_sequence
import torch.nn.functional as F
import gc

torch.manual_seed(42)
device = 'cuda:1' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda:1

# %%
def get_unique_list(row, configs):
    c = len(row["node_config_feat"])
    unique_list = []
    for i in range(c):
        if (len(unique_list) == configs):
            break
        for j in range(i + 1, c):
            conf_i = row["node_config_feat"][i]
            conf_j = row["node_config_feat"][j]
            if (np.array_equal(conf_i, conf_j)):
                break
        else:
            unique_list.append(i)
            
    return unique_list

# %%
def compress_layout_df(directory):
    MAX_CONFIGS = 1000
    splits = ["train","valid", "test"]

    target_directory = directory.split("/")
    target_directory[2] = "working"
    target_directory = "/".join(target_directory)
    
    for split in splits:
        path = os.path.join(directory, split)
        files = os.listdir(path)
        os.makedirs(os.path.join(target_directory, split))
        
        for file in files:
            d = dict(np.load(os.path.join(path,file), allow_pickle = True))
            # Only keep configurable nodes
            d["node_feat"] = d["node_feat"][d["node_config_ids"]]
            d["node_opcode"] = d["node_opcode"][d["node_config_ids"]]
            
            d["edge_index"] = d["edge_index"][np.isin(d["edge_index"], d["node_config_ids"]).all(1)]
            if d["edge_index"].size > 0: 
                value_to_idx = {val: idx for idx, val in enumerate(d["node_config_ids"])}
                convert = np.vectorize(value_to_idx.get)
                d["edge_index"] = convert(d["edge_index"])

            # if split == "train":
            #     unique_list = get_unique_list(d, MAX_CONFIGS)
            #     d["node_config_feat"] = d["node_config_feat"][unique_list]
            #     d["config_runtime"] = d["config_runtime"][unique_list]

            if split != "test":
                c = min(len(d['config_runtime']), MAX_CONFIGS)
                d["node_config_feat"] = d["node_config_feat"][:c]
                d["config_runtime"] = d["config_runtime"][:c]
            d['filename'] = file
            np.savez_compressed(os.path.join(target_directory, split, file), **d)
    print(f"target directory {target_directory} done")

# %%
layout_path_list = [
     "/kaggle/input/predict-ai-model-runtime/npz_all/npz/layout/nlp/random/",
     "/kaggle/input/predict-ai-model-runtime/npz_all/npz/layout/nlp/default/",
     "/kaggle/input/predict-ai-model-runtime/npz_all/npz/layout/xla/random/",
     "/kaggle/input/predict-ai-model-runtime/npz_all/npz/layout/xla/default/",
    ]
layout_path_list
# Out:
# ['/kaggle/input/predict-ai-model-runtime/npz_all/npz/layout/nlp/random/',
#  '/kaggle/input/predict-ai-model-runtime/npz_all/npz/layout/nlp/default/',
#  '/kaggle/input/predict-ai-model-runtime/npz_all/npz/layout/xla/random/',
#  '/kaggle/input/predict-ai-model-runtime/npz_all/npz/layout/xla/default/']

# %%
# ! rm -rf /kaggle/working/predict-ai-model-runtime

# %%
for path in layout_path_list:
    compress_layout_df(path)
# Out:
# target directory /kaggle/working/predict-ai-model-runtime/npz_all/npz/layout/nlp/random/ done
# target directory /kaggle/working/predict-ai-model-runtime/npz_all/npz/layout/nlp/default/ done
# target directory /kaggle/working/predict-ai-model-runtime/npz_all/npz/layout/xla/random/ done
# target directory /kaggle/working/predict-ai-model-runtime/npz_all/npz/layout/xla/default/ done

# %%
def load_saved(directory):
    directory = directory.split("/")
    directory[2] = "working"
    directory = "/".join(directory)
    splits = ["train","valid", "test"]
    dfs = dict()
    
    for split in splits:
        path = os.path.join(directory, split)
        files = os.listdir(path)
        list_df = []
        
        for file in files:
            d = dict(np.load(os.path.join(path,file), allow_pickle = True))
            list_df.append(d)
        dfs[split] = pd.DataFrame.from_dict(list_df)
    return dfs

# %%
class LayoutDataset(Dataset):
    def __init__(self, df):
        self.df = df
        
    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        node_config_feat = torch.tensor(row['node_config_feat'].astype(np.float32))
        node_feat = torch.tensor(row['node_feat'].astype(np.float32))
        node_opcode = torch.tensor(row['node_opcode'].astype(np.int32))
        edge_index = torch.tensor(np.swapaxes(row['edge_index'],0,1).astype(np.int32))
        target = torch.tensor(row['config_runtime'].astype(np.float32))
        
        
        # CRITICAL FIX: Normalize features to same scale
        node_feat = (node_feat - node_feat.mean()) / (node_feat.std() + 1e-8)
        node_config_feat = (node_config_feat - node_config_feat.mean()) / (node_config_feat.std() + 1e-8)
        
        target = (target - min(target)) / (max(target) - min(target))
        
        return node_config_feat, node_feat, node_opcode, edge_index, target

# %%
class LayoutModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        
        self.embedding = torch.nn.Embedding(120, 16)

        # Process each node with config features
        self.node_encoder = torch.nn.Sequential(
            nn.Linear(174, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
        )
        
        # Aggregate nodes into config representation
        self.config_encoder = torch.nn.Sequential(
            nn.Linear(128*3, 64),  # mean, max, std = 32*3 = 96
            nn.ReLU(),
            nn.Linear(64, 16),
            nn.ReLU(),
        )
        
        # Final prediction
        self.predictor = nn.Linear(16, 1)

    def forward(self, x_cfg: Tensor, x_feat: Tensor, x_op: Tensor, edge_index: Tensor) -> Tensor:
        x_op = self.embedding(x_op)
        # x_cfg: (c, nc, 18)
        # x_feat: (nc, 140)
        # x_op: (nc, 16)
        x_feat = x_feat.unsqueeze(0).expand(x_cfg.shape[0], -1, -1)
        x_op = x_op.unsqueeze(0).expand(x_cfg.shape[0], -1, -1)
        
        # Concatenate all features
        x = torch.concat([x_feat, x_op, x_cfg], axis=2)  # (c, nc, 174)
        
        # Process each node
        x = self.node_encoder(x)  # (c, nc, 32)
        
        # Aggregate with multiple statistics to preserve distinguishability
        x_mean = x.mean(1)  # (c, 32)
        x_max = x.max(1).values  # (c, 32)
        x_std = x.std(1)  # (c, 32)
        x = torch.cat([x_mean, x_max, x_std], dim=1)  # (c, 96)
        
        # Encode aggregated config representation
        x = self.config_encoder(x)  # (c, 32)
        
        # Predict runtime
        x = self.predictor(x)  # (c, 1)
        x = torch.flatten(x)
        
        return x

# %%
class RuntimeRankNetLoss(nn.Module):
    """
    RankNet Loss for runtime optimization where LOWER runtime is better.
    Processes one row/query at a time.
    
    Args:
        reduction (str): 'none' | 'mean' | 'sum'
        margin (float): Ignore pairs with runtime differences smaller than this
        temperature (float): Temperature for sigmoid function
    """
    
    def __init__(self, reduction='mean', margin=0.0, temperature=1.0):
        super(RuntimeRankNetLoss, self).__init__()
        self.reduction = reduction
        self.margin = margin
        self.temperature = temperature
        
    def forward(self, predicted_runtimes, true_runtimes, mask=None):
        """
        Forward pass for single row of runtime data.
        
        Args:
            predicted_runtimes (torch.Tensor): Predicted runtimes, shape (n_items,)
            true_runtimes (torch.Tensor): True runtimes, shape (n_items,)
            mask (torch.Tensor, optional): Mask for valid items, shape (n_items,)
            
        Returns:
            torch.Tensor: Computed RankNet loss
        """
        # Ensure inputs are 1D
        predicted_runtimes = predicted_runtimes.squeeze()
        true_runtimes = true_runtimes.squeeze()
        
        n_items = predicted_runtimes.shape[0]
        device = predicted_runtimes.device
        
        # Create mask if not provided
        if mask is None:
            mask = torch.ones(n_items, dtype=torch.bool, device=device)
        
        # Get indices of valid items
        valid_indices = torch.where(mask)[0]
        if len(valid_indices) < 2:
            return torch.tensor(0.0, device=device)
        
        # Extract valid runtimes
        pred_valid = predicted_runtimes[valid_indices]
        true_valid = true_runtimes[valid_indices]
        n_valid = len(pred_valid)
        
        # Expand to compute all pairwise comparisons
        pred_i = pred_valid.unsqueeze(1).expand(n_valid, n_valid)
        pred_j = pred_valid.unsqueeze(0).expand(n_valid, n_valid)
        
        true_i = true_valid.unsqueeze(1).expand(n_valid, n_valid)
        true_j = true_valid.unsqueeze(0).expand(n_valid, n_valid)
        
        # For runtimes: LOWER is BETTER
        # So if true_i < true_j, then i is better than j (P_ij = 1)
        P_ij = (true_i < true_j).float()
        
        # Apply margin to ignore small differences
        if self.margin > 0:
            significant_diff = (torch.abs(true_i - true_j) > self.margin).float()
            P_ij = P_ij * significant_diff
        
        # Compute predicted probability that i is better than j
        # For runtimes: if pred_j - pred_i is large positive, then i is much better than j
        pred_diff = (pred_j - pred_i) / self.temperature  # positive when i is better
        
        # RankNet loss calculation
        # We want to maximize sigmoid(pred_diff) when P_ij = 1
        # and minimize it when P_ij = 0
        losses = F.binary_cross_entropy_with_logits(
            pred_diff, P_ij, reduction='none'
        )
        
        # Use only upper triangle to avoid duplicate pairs (i < j)
        triu_mask = torch.triu(torch.ones(n_valid, n_valid, device=device), diagonal=1)
        losses = losses * triu_mask
        valid_pairs = triu_mask.sum()
        
        if valid_pairs == 0:
            return torch.tensor(0.0, device=device)
        
        if self.reduction == 'mean':
            return losses.sum() / valid_pairs
        elif self.reduction == 'sum':
            return losses.sum()
        else:  # 'none'
            return losses

# %%
sub = pd.read_csv('/kaggle/input/predict-ai-model-runtime/sample_submission.csv')

# %%
def compute_score(out, target):
    return kendalltau(np.argsort(out.detach().cpu().numpy()), np.argsort(target.detach().cpu().numpy())).correlation

# %%
class EarlyStopper:
    def __init__(self, patience=3, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = np.inf

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
# Ideas:

# %%
for path in layout_path_list:
    EPOCHS = 200  # Increased for better training
    model = LayoutModel().to(device)
    dfs = load_saved(path)
    train_dataset = LayoutDataset(dfs["train"])
    valid_dataset = LayoutDataset(dfs["valid"])
    test_dataset = LayoutDataset(dfs["test"])
    criterion = RuntimeRankNetLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, EPOCHS)
    # early_stopper = EarlyStopper(patience = 5, min_delta = -0.01)
    
    best_tau = -float('inf')
    
    for epoch in range(EPOCHS):
        model.train()
        pbar = tqdm(range(len(train_dataset)))
        loss_sum = 0
        n = 0
        
        for i in pbar:
            node_config_feat, node_feat, node_opcode, edge_index, target = train_dataset[i]
            node_config_feat, node_feat, node_opcode, edge_index, target = (
                node_config_feat.to(device), node_feat.to(device), 
                node_opcode.to(device), edge_index.to(device), target.to(device)
            )
            
            # DEBUG INFO (first iteration only)
            if i == 0 and epoch == 0:
                print(f'\n=== DEBUG INFO ===')
                print(f'node_config_feat: {node_config_feat.shape}, variance: {node_config_feat.var():.6f}')
                print(f'node_feat: {node_feat.shape}, variance: {node_feat.var():.6f}')
                print(f'target range: [{target.min():.3f}, {target.max():.3f}]')
                
                out_test = model(node_config_feat, node_feat, node_opcode, edge_index)
                print(f'output: mean={out_test.mean():.6f}, std={out_test.std():.6f}')
                print(f'output range: [{out_test.min():.6f}, {out_test.max():.6f}]')
                print('==================\n')
            
            out = model(node_config_feat, node_feat, node_opcode, edge_index)
            loss = criterion(out, target)
            
            optimizer.zero_grad()
            loss.backward()
            
            # Check gradient norm on first iteration
            if i == 0:
                grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), float('inf'))
                # print(f'Epoch {epoch}: Gradient norm = {grad_norm:.4f}')
            
            # Gradient clipping (reasonable value)
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            optimizer.step()
            
            loss_sum += loss.item()
            n += 1
            tau = compute_score(out, target)
            pbar.set_description(f'[Training] Epoch: {epoch}, running loss: {(loss_sum/n):.3f}, current loss: {(loss.item()):.3f}, tau: {tau:.3f}')
        
        # Validation
        model.eval()
        pbar = tqdm(range(len(valid_dataset)))
        loss_sum = 0
        n = 0
        with torch.no_grad():
            for i in pbar:
                node_config_feat, node_feat, node_opcode, edge_index, target = valid_dataset[i]
                node_config_feat, node_feat, node_opcode, edge_index, target = (
                    node_config_feat.to(device), node_feat.to(device), 
                    node_opcode.to(device), edge_index.to(device), target.to(device)
                )
            
                out = model(node_config_feat, node_feat, node_opcode, edge_index)
                loss = criterion(out, target)
                loss_sum += loss.item()
                n += 1
                tau = compute_score(out, target)
                
                pbar.set_description(f'[Validation] Epoch: {epoch}, running loss: {(loss_sum/n):.3f}, current loss: {(loss.item()):.3f} tau: {tau:.3f}')
        
        scheduler.step()
    
    # Inference on test set
    predictions = []
    model.eval()
    pbar = tqdm(range(len(test_dataset)))
    with torch.no_grad():
        for i in pbar:
            node_config_feat, node_feat, node_opcode, edge_index, target = test_dataset[i]
            node_config_feat, node_feat, node_opcode, edge_index, target = (
                node_config_feat.to(device), node_feat.to(device), 
                node_opcode.to(device), edge_index.to(device), target.to(device)
            )
                
            out = model(node_config_feat, node_feat, node_opcode, edge_index)
            predictions.append(np.argsort(out.detach().cpu().numpy()))
    
    collection = path.split("/")[-3:-1]
    for i, filename in enumerate(dfs["test"]['filename'].values):
        id = f"layout:{collection[0]}:{collection[1]}:{filename.item()[:-4]}"
        sub.loc[sub.ID == id, 'TopConfigs'] = ';'.join(predictions[i].astype(str))
        # print(f"wrote id: {id}")
# Out:
#   0%|          | 0/207 [00:00<?, ?it/s]
# === DEBUG INFO ===
# node_config_feat: torch.Size([1000, 346, 18]), variance: 1.000000
# node_feat: torch.Size([346, 140]), variance: 1.000000
# target range: [0.000, 1.000]
# output: mean=0.224122, std=0.000909
# output range: [0.221472, 0.226499]
# ==================
# [Training] Epoch: 0, running loss: 0.564, current loss: 0.455, tau: -0.005: 100%|██████████| 207/207 [00:16<00:00, 12.19it/s]
# [Validation] Epoch: 0, running loss: 0.437, current loss: 0.412 tau: 0.022: 100%|██████████| 20/20 [00:00<00:00, 20.64it/s]
# [Training] Epoch: 1, running loss: 0.444, current loss: 0.459, tau: -0.010: 100%|██████████| 207/207 [00:13<00:00, 14.86it/s]
# [Validation] Epoch: 1, running loss: 0.435, current loss: 0.372 tau: 0.018: 100%|██████████| 20/20 [00:00<00:00, 21.66it/s]
# [Training] Epoch: 2, running loss: 0.425, current loss: 0.401, tau: 0.023: 100%|██████████| 207/207 [00:14<00:00, 14.77it/s]
# [Validation] Epoch: 2, running loss: 0.412, current loss: 0.311 tau: -0.003: 100%|██████████| 20/20 [00:00<00:00, 21.67it/s]
# [Training] Epoch: 3, running loss: 0.407, current loss: 0.359, tau: -0.027: 100%|██████████| 207/207 [00:14<00:00, 14.75it/s]
# [Validation] Epoch: 3, running loss: 0.383, current loss: 0.278 tau: 0.038: 100%|██████████| 20/20 [00:00<00:00, 22.44it/s]
# [Training] Epoch: 4, running loss: 0.405, current loss: 0.389, tau: 0.028: 100%|██████████| 207/207 [00:14<00:00, 14.61it/s]
# [Validation] Epoch: 4, running loss: 0.394, current loss: 0.314 tau: 0.012: 100%|██████████| 20/20 [00:00<00:00, 21.78it/s]
# [Training] Epoch: 5, running loss: 0.397, current loss: 0.364, tau: -0.033: 100%|██████████| 207/207 [00:14<00:00, 14.33it/s]
# [Validation] Epoch: 5, running loss: 0.381, current loss: 0.295 tau: 0.045: 100%|██████████| 20/20 [00:00<00:00, 22.08it/s]
# [Training] Epoch: 6, running loss: 0.389, current loss: 0.352, tau: 0.002: 100%|██████████| 207/207 [00:14<00:00, 14.33it/s]
# [Validation] Epoch: 6, running loss: 0.372, current loss: 0.292 tau: -0.025: 100%|██████████| 20/20 [00:00<00:00, 21.61it/s]
# [Training] Epoch: 7, running loss: 0.386, current loss: 0.331, tau: -0.021: 100%|██████████| 207/207 [00:14<00:00, 14.18it/s]
# [Validation] Epoch: 7, running loss: 0.375, current loss: 0.310 tau: 0.026: 100%|██████████| 20/20 [00:00<00:00, 23.07it/s]
# [Training] Epoch: 8, running loss: 0.387, current loss: 0.325, tau: -0.027: 100%|██████████| 207/207 [00:14<00:00, 14.42it/s]
# [Validation] Epoch: 8, running loss: 0.367, current loss: 0.286 tau: -0.009: 100%|██████████| 20/20 [00:00<00:00, 22.89it/s]
# [Training] Epoch: 9, running loss: 0.382, current loss: 0.326, tau: 0.002: 100%|██████████| 207/207 [00:14<00:00, 14.07it/s]
# [Validation] Epoch: 9, running loss: 0.363, current loss: 0.274 tau: 0.026: 100%|██████████| 20/20 [00:00<00:00, 23.13it/s]
# [Training] Epoch: 10, running loss: 0.379, current loss: 0.336, tau: 0.002: 100%|██████████| 207/207 [00:14<00:00, 14.36it/s]
# [Validation] Epoch: 10, running loss: 0.368, current loss: 0.262 tau: 0.023: 100%|██████████| 20/20 [00:00<00:00, 22.71it/s]
# [Training] Epoch: 11, running loss: 0.374, current loss: 0.337, tau: 0.042: 100%|██████████| 207/207 [00:14<00:00, 14.41it/s]
# [Validation] Epoch: 11, running loss: 0.370, current loss: 0.293 tau: 0.023: 100%|██████████| 20/20 [00:01<00:00, 19.63it/s]
# [Training] Epoch: 12, running loss: 0.373, current loss: 0.315, tau: -0.010: 100%|██████████| 207/207 [00:14<00:00, 14.56it/s]
# [Validation] Epoch: 12, running loss: 0.369, current loss: 0.264 tau: 0.030: 100%|██████████| 20/20 [00:00<00:00, 22.46it/s]
# [Training] Epoch: 13, running loss: 0.368, current loss: 0.315, tau: 0.004: 100%|██████████| 207/207 [00:14<00:00, 14.53it/s]
# [Validation] Epoch: 13, running loss: 0.358, current loss: 0.265 tau: -0.029: 100%|██████████| 20/20 [00:00<00:00, 21.50it/s]
# [Training] Epoch: 14, running loss: 0.368, current loss: 0.307, tau: -0.015: 100%|██████████| 207/207 [00:14<00:00, 14.14it/s]
# [Validation] Epoch: 14, running loss: 0.355, current loss: 0.266 tau: 0.046: 100%|██████████| 20/20 [00:00<00:00, 21.15it/s]
# [Training] Epoch: 15, running loss: 0.368, current loss: 0.320, tau: -0.001: 100%|██████████| 207/207 [00:14<00:00, 14.27it/s]
# [Validation] Epoch: 15, running loss: 0.359, current loss: 0.253 tau: 0.020: 100%|██████████| 20/20 [00:00<00:00, 23.15it/s]
# [Training] Epoch: 16, running loss: 0.363, current loss: 0.316, tau: 0.026: 100%|██████████| 207/207 [00:14<00:00, 14.32it/s]
# [Validation] Epoch: 16, running loss: 0.354, current loss: 0.270 tau: -0.028: 100%|██████████| 20/20 [00:00<00:00, 21.71it/s]
# [Training] Epoch: 17, running loss: 0.362, current loss: 0.322, tau: 0.021: 100%|██████████| 207/207 [00:14<00:00, 14.44it/s]
# [Validation] Epoch: 17, running loss: 0.351, current loss: 0.254 tau: -0.007: 100%|██████████| 20/20 [00:00<00:00, 20.75it/s]
# [Training] Epoch: 18, running loss: 0.357, current loss: 0.311, tau: -0.011: 100%|██████████| 207/207 [00:14<00:00, 14.38it/s]
# [Validation] Epoch: 18, running loss: 0.353, current loss: 0.253 tau: 0.004: 100%|██████████| 20/20 [00:00<00:00, 22.78it/s]
# [Training] Epoch: 19, running loss: 0.355, current loss: 0.304, tau: 0.019: 100%|██████████| 207/207 [00:14<00:00, 14.44it/s]
# [Validation] Epoch: 19, running loss: 0.351, current loss: 0.259 tau: 0.031: 100%|██████████| 20/20 [00:00<00:00, 22.01it/s]
# [Training] Epoch: 20, running loss: 0.355, current loss: 0.305, tau: 0.001: 100%|██████████| 207/207 [00:14<00:00, 14.45it/s]
# [Validation] Epoch: 20, running loss: 0.343, current loss: 0.271 tau: -0.012: 100%|██████████| 20/20 [00:00<00:00, 23.07it/s]
# [Training] Epoch: 21, running loss: 0.354, current loss: 0.302, tau: 0.025: 100%|██████████| 207/207 [00:14<00:00, 14.24it/s]
# [Validation] Epoch: 21, running loss: 0.348, current loss: 0.270 tau: 0.022: 100%|██████████| 20/20 [00:00<00:00, 21.10it/s]
# [Training] Epoch: 22, running loss: 0.354, current loss: 0.304, tau: -0.023: 100%|██████████| 207/207 [00:14<00:00, 14.44it/s]
# [Validation] Epoch: 22, running loss: 0.347, current loss: 0.260 tau: -0.032: 100%|██████████| 20/20 [00:00<00:00, 22.59it/s]
# [Training] Epoch: 23, running loss: 0.351, current loss: 0.312, tau: 0.015: 100%|██████████| 207/207 [00:14<00:00, 14.48it/s]
# [Validation] Epoch: 23, running loss: 0.343, current loss: 0.271 tau: -0.015: 100%|██████████| 20/20 [00:00<00:00, 22.59it/s]
# [Training] Epoch: 24, running loss: 0.350, current loss: 0.310, tau: 0.007: 100%|██████████| 207/207 [00:14<00:00, 14.49it/s]
# [Validation] Epoch: 24, running loss: 0.344, current loss: 0.279 tau: -0.007: 100%|██████████| 20/20 [00:00<00:00, 21.28it/s]
# [Training] Epoch: 25, running loss: 0.349, current loss: 0.300, tau: 0.001: 100%|██████████| 207/207 [00:14<00:00, 14.20it/s]
# [Validation] Epoch: 25, running loss: 0.343, current loss: 0.284 tau: 0.018: 100%|██████████| 20/20 [00:00<00:00, 21.41it/s]
# [Training] Epoch: 26, running loss: 0.348, current loss: 0.301, tau: -0.001: 100%|██████████| 207/207 [00:14<00:00, 14.31it/s]
# [Validation] Epoch: 26, running loss: 0.349, current loss: 0.275 tau: 0.011: 100%|██████████| 20/20 [00:00<00:00, 22.57it/s]
# [Training] Epoch: 27, running loss: 0.349, current loss: 0.330, tau: -0.013: 100%|██████████| 207/207 [00:14<00:00, 14.54it/s]
# [Validation] Epoch: 27, running loss: 0.353, current loss: 0.286 tau: 0.046: 100%|██████████| 20/20 [00:01<00:00, 18.41it/s]
# [Training] Epoch: 28, running loss: 0.347, current loss: 0.313, tau: -0.026: 100%|██████████| 207/207 [00:14<00:00, 14.49it/s]
# [Validation] Epoch: 28, running loss: 0.343, current loss: 0.265 tau: 0.027: 100%|██████████| 20/20 [00:00<00:00, 21.91it/s]
# [Training] Epoch: 29, running loss: 0.344, current loss: 0.311, tau: 0.023: 100%|██████████| 207/207 [00:14<00:00, 14.56it/s]
# [Validation] Epoch: 29, running loss: 0.346, current loss: 0.263 tau: 0.006: 100%|██████████| 20/20 [00:00<00:00, 23.35it/s]
# [Training] Epoch: 30, running loss: 0.342, current loss: 0.315, tau: 0.029: 100%|██████████| 207/207 [00:14<00:00, 14.29it/s]
# [Validation] Epoch: 30, running loss: 0.342, current loss: 0.262 tau: -0.015: 100%|██████████| 20/20 [00:00<00:00, 22.63it/s]
# [Training] Epoch: 31, running loss: 0.342, current loss: 0.308, tau: -0.029: 100%|██████████| 207/207 [00:14<00:00, 14.62it/s]
# [Validation] Epoch: 31, running loss: 0.341, current loss: 0.269 tau: 0.026: 100%|██████████| 20/20 [00:00<00:00, 23.88it/s]
# [Training] Epoch: 32, running loss: 0.344, current loss: 0.305, tau: 0.028: 100%|██████████| 207/207 [00:14<00:00, 14.77it/s]
# [Validation] Epoch: 32, running loss: 0.342, current loss: 0.268 tau: -0.030: 100%|██████████| 20/20 [00:00<00:00, 22.14it/s]
# [Training] Epoch: 33, running loss: 0.340, current loss: 0.311, tau: 0.006: 100%|██████████| 207/207 [00:13<00:00, 14.83it/s]
# [Validation] Epoch: 33, running loss: 0.342, current loss: 0.272 tau: -0.035: 100%|██████████| 20/20 [00:00<00:00, 23.59it/s]
# [Training] Epoch: 34, running loss: 0.343, current loss: 0.339, tau: 0.055: 100%|██████████| 207/207 [00:14<00:00, 14.65it/s]
# [Validation] Epoch: 34, running loss: 0.342, current loss: 0.270 tau: 0.017: 100%|██████████| 20/20 [00:00<00:00, 22.90it/s]
# [Training] Epoch: 35, running loss: 0.342, current loss: 0.308, tau: 0.007: 100%|██████████| 207/207 [00:13<00:00, 14.80it/s]
# [Validation] Epoch: 35, running loss: 0.335, current loss: 0.263 tau: 0.032: 100%|██████████| 20/20 [00:00<00:00, 22.26it/s]
# [Training] Epoch: 36, running loss: 0.340, current loss: 0.334, tau: -0.019: 100%|██████████| 207/207 [00:14<00:00, 14.70it/s]
# [Validation] Epoch: 36, running loss: 0.342, current loss: 0.266 tau: 0.029: 100%|██████████| 20/20 [00:00<00:00, 23.52it/s]
# [Training] Epoch: 37, running loss: 0.337, current loss: 0.296, tau: -0.001: 100%|██████████| 207/207 [00:14<00:00, 14.69it/s]
# [Validation] Epoch: 37, running loss: 0.337, current loss: 0.258 tau: -0.015: 100%|██████████| 20/20 [00:00<00:00, 23.81it/s]
# [Training] Epoch: 38, running loss: 0.336, current loss: 0.332, tau: -0.012: 100%|██████████| 207/207 [00:13<00:00, 15.00it/s]
# [Validation] Epoch: 38, running loss: 0.342, current loss: 0.262 tau: 0.018: 100%|██████████| 20/20 [00:00<00:00, 22.29it/s]
# [Training] Epoch: 39, running loss: 0.334, current loss: 0.309, tau: 0.010: 100%|██████████| 207/207 [00:13<00:00, 14.79it/s]
# [Validation] Epoch: 39, running loss: 0.340, current loss: 0.260 tau: -0.006: 100%|██████████| 20/20 [00:00<00:00, 23.01it/s]
# [Training] Epoch: 40, running loss: 0.332, current loss: 0.306, tau: -0.011: 100%|██████████| 207/207 [00:13<00:00, 14.94it/s]
# [Validation] Epoch: 40, running loss: 0.340, current loss: 0.263 tau: 0.024: 100%|██████████| 20/20 [00:00<00:00, 23.55it/s]
# [Training] Epoch: 41, running loss: 0.328, current loss: 0.288, tau: -0.032: 100%|██████████| 207/207 [00:14<00:00, 14.77it/s]
# [Validation] Epoch: 41, running loss: 0.334, current loss: 0.283 tau: 0.009: 100%|██████████| 20/20 [00:00<00:00, 24.10it/s]
# [Training] Epoch: 42, running loss: 0.331, current loss: 0.332, tau: -0.005: 100%|██████████| 207/207 [00:13<00:00, 14.99it/s]
# [Validation] Epoch: 42, running loss: 0.335, current loss: 0.271 tau: -0.002: 100%|██████████| 20/20 [00:00<00:00, 23.32it/s]
# [Training] Epoch: 43, running loss: 0.326, current loss: 0.359, tau: 0.008: 100%|██████████| 207/207 [00:14<00:00, 14.74it/s]
# [Validation] Epoch: 43, running loss: 0.333, current loss: 0.265 tau: 0.033: 100%|██████████| 20/20 [00:00<00:00, 23.27it/s]
# [Training] Epoch: 44, running loss: 0.324, current loss: 0.339, tau: -0.054: 100%|██████████| 207/207 [00:13<00:00, 14.82it/s]
# [Validation] Epoch: 44, running loss: 0.330, current loss: 0.262 tau: 0.020: 100%|██████████| 20/20 [00:00<00:00, 23.38it/s]
# [Training] Epoch: 45, running loss: 0.320, current loss: 0.332, tau: 0.003: 100%|██████████| 207/207 [00:13<00:00, 14.95it/s]
# [Validation] Epoch: 45, running loss: 0.321, current loss: 0.243 tau: 0.020: 100%|██████████| 20/20 [00:00<00:00, 23.27it/s]
# [Training] Epoch: 46, running loss: 0.321, current loss: 0.305, tau: -0.005: 100%|██████████| 207/207 [00:14<00:00, 14.62it/s]
# [Validation] Epoch: 46, running loss: 0.324, current loss: 0.260 tau: -0.025: 100%|██████████| 20/20 [00:00<00:00, 23.31it/s]
# [Training] Epoch: 47, running loss: 0.317, current loss: 0.305, tau: 0.008: 100%|██████████| 207/207 [00:14<00:00, 14.46it/s]
# [Validation] Epoch: 47, running loss: 0.324, current loss: 0.286 tau: -0.006: 100%|██████████| 20/20 [00:00<00:00, 23.62it/s]
# [Training] Epoch: 48, running loss: 0.317, current loss: 0.331, tau: -0.010: 100%|██████████| 207/207 [00:14<00:00, 14.56it/s]
# [Validation] Epoch: 48, running loss: 0.332, current loss: 0.260 tau: 0.020: 100%|██████████| 20/20 [00:00<00:00, 23.25it/s]
# [Training] Epoch: 49, running loss: 0.319, current loss: 0.331, tau: 0.008: 100%|██████████| 207/207 [00:14<00:00, 14.44it/s]
# [Validation] Epoch: 49, running loss: 0.315, current loss: 0.263 tau: 0.005: 100%|██████████| 20/20 [00:00<00:00, 22.83it/s]
# [Training] Epoch: 50, running loss: 0.313, current loss: 0.283, tau: -0.011: 100%|██████████| 207/207 [00:14<00:00, 14.16it/s]
# [Validation] Epoch: 50, running loss: 0.315, current loss: 0.255 tau: 0.012: 100%|██████████| 20/20 [00:00<00:00, 21.80it/s]
# [Training] Epoch: 51, running loss: 0.308, current loss: 0.318, tau: 0.009: 100%|██████████| 207/207 [00:14<00:00, 13.93it/s]
# [Validation] Epoch: 51, running loss: 0.317, current loss: 0.262 tau: -0.008: 100%|██████████| 20/20 [00:00<00:00, 21.92it/s]
# [Training] Epoch: 52, running loss: 0.306, current loss: 0.322, tau: 0.012: 100%|██████████| 207/207 [00:14<00:00, 14.39it/s]
# [Validation] Epoch: 52, running loss: 0.322, current loss: 0.245 tau: -0.003: 100%|██████████| 20/20 [00:01<00:00, 19.36it/s]
# [Training] Epoch: 53, running loss: 0.311, current loss: 0.303, tau: -0.015: 100%|██████████| 207/207 [00:14<00:00, 14.16it/s]
# [Validation] Epoch: 53, running loss: 0.323, current loss: 0.253 tau: 0.031: 100%|██████████| 20/20 [00:00<00:00, 22.68it/s]
# [Training] Epoch: 54, running loss: 0.306, current loss: 0.269, tau: 0.010: 100%|██████████| 207/207 [00:14<00:00, 14.23it/s]
# [Validation] Epoch: 54, running loss: 0.313, current loss: 0.245 tau: -0.006: 100%|██████████| 20/20 [00:00<00:00, 22.86it/s]
# [Training] Epoch: 55, running loss: 0.299, current loss: 0.312, tau: -0.001: 100%|██████████| 207/207 [00:14<00:00, 14.21it/s]
# [Validation] Epoch: 55, running loss: 0.309, current loss: 0.253 tau: -0.010: 100%|██████████| 20/20 [00:00<00:00, 22.26it/s]
# [Training] Epoch: 56, running loss: 0.299, current loss: 0.306, tau: 0.010: 100%|██████████| 207/207 [00:14<00:00, 14.48it/s]
# [Validation] Epoch: 56, running loss: 0.313, current loss: 0.276 tau: -0.001: 100%|██████████| 20/20 [00:00<00:00, 22.33it/s]
# [Training] Epoch: 57, running loss: 0.297, current loss: 0.303, tau: -0.047: 100%|██████████| 207/207 [00:14<00:00, 14.03it/s]
# [Validation] Epoch: 57, running loss: 0.298, current loss: 0.245 tau: 0.010: 100%|██████████| 20/20 [00:00<00:00, 22.21it/s]
# [Training] Epoch: 58, running loss: 0.294, current loss: 0.293, tau: -0.003: 100%|██████████| 207/207 [00:14<00:00, 14.37it/s]
# [Validation] Epoch: 58, running loss: 0.304, current loss: 0.262 tau: -0.008: 100%|██████████| 20/20 [00:00<00:00, 22.36it/s]
# [Training] Epoch: 59, running loss: 0.290, current loss: 0.287, tau: -0.022: 100%|██████████| 207/207 [00:14<00:00, 14.15it/s]
# [Validation] Epoch: 59, running loss: 0.312, current loss: 0.257 tau: 0.004: 100%|██████████| 20/20 [00:00<00:00, 21.91it/s]
# [Training] Epoch: 60, running loss: 0.287, current loss: 0.287, tau: 0.001: 100%|██████████| 207/207 [00:14<00:00, 14.28it/s]
# [Validation] Epoch: 60, running loss: 0.315, current loss: 0.242 tau: -0.001: 100%|██████████| 20/20 [00:00<00:00, 22.15it/s]
# [Training] Epoch: 61, running loss: 0.297, current loss: 0.280, tau: -0.003: 100%|██████████| 207/207 [00:14<00:00, 14.41it/s]
# [Validation] Epoch: 61, running loss: 0.297, current loss: 0.252 tau: -0.000: 100%|██████████| 20/20 [00:00<00:00, 23.04it/s]
# [Training] Epoch: 62, running loss: 0.287, current loss: 0.292, tau: -0.008: 100%|██████████| 207/207 [00:14<00:00, 14.30it/s]
# [Validation] Epoch: 62, running loss: 0.300, current loss: 0.247 tau: 0.054: 100%|██████████| 20/20 [00:00<00:00, 23.07it/s]
# [Training] Epoch: 63, running loss: 0.282, current loss: 0.270, tau: 0.046: 100%|██████████| 207/207 [00:14<00:00, 14.51it/s]
# [Validation] Epoch: 63, running loss: 0.305, current loss: 0.242 tau: 0.015: 100%|██████████| 20/20 [00:00<00:00, 21.46it/s]
# [Training] Epoch: 64, running loss: 0.281, current loss: 0.273, tau: 0.008: 100%|██████████| 207/207 [00:14<00:00, 14.28it/s]
# [Validation] Epoch: 64, running loss: 0.307, current loss: 0.266 tau: 0.021: 100%|██████████| 20/20 [00:00<00:00, 22.43it/s]
# [Training] Epoch: 65, running loss: 0.279, current loss: 0.292, tau: -0.025: 100%|██████████| 207/207 [00:14<00:00, 14.46it/s]
# [Validation] Epoch: 65, running loss: 0.311, current loss: 0.278 tau: -0.024: 100%|██████████| 20/20 [00:00<00:00, 23.52it/s]
# [Training] Epoch: 66, running loss: 0.275, current loss: 0.262, tau: 0.003: 100%|██████████| 207/207 [00:14<00:00, 14.31it/s]
# [Validation] Epoch: 66, running loss: 0.286, current loss: 0.247 tau: -0.018: 100%|██████████| 20/20 [00:00<00:00, 21.99it/s]
# [Training] Epoch: 67, running loss: 0.273, current loss: 0.268, tau: -0.015: 100%|██████████| 207/207 [00:14<00:00, 14.38it/s]
# [Validation] Epoch: 67, running loss: 0.288, current loss: 0.251 tau: 0.023: 100%|██████████| 20/20 [00:00<00:00, 22.74it/s]
# [Training] Epoch: 68, running loss: 0.271, current loss: 0.267, tau: -0.015: 100%|██████████| 207/207 [00:14<00:00, 14.35it/s]
# [Validation] Epoch: 68, running loss: 0.284, current loss: 0.239 tau: 0.027: 100%|██████████| 20/20 [00:01<00:00, 19.56it/s]
# [Training] Epoch: 69, running loss: 0.278, current loss: 0.271, tau: -0.021: 100%|██████████| 207/207 [00:14<00:00, 14.66it/s]
# [Validation] Epoch: 69, running loss: 0.289, current loss: 0.260 tau: -0.017: 100%|██████████| 20/20 [00:00<00:00, 23.28it/s]
# [Training] Epoch: 70, running loss: 0.270, current loss: 0.250, tau: 0.002: 100%|██████████| 207/207 [00:14<00:00, 14.78it/s]
# [Validation] Epoch: 70, running loss: 0.276, current loss: 0.256 tau: -0.007: 100%|██████████| 20/20 [00:00<00:00, 23.92it/s]
# [Training] Epoch: 71, running loss: 0.269, current loss: 0.238, tau: -0.028: 100%|██████████| 207/207 [00:14<00:00, 14.58it/s]
# [Validation] Epoch: 71, running loss: 0.274, current loss: 0.252 tau: 0.033: 100%|██████████| 20/20 [00:00<00:00, 23.90it/s]
# [Training] Epoch: 72, running loss: 0.269, current loss: 0.252, tau: -0.030: 100%|██████████| 207/207 [00:13<00:00, 14.84it/s]
# [Validation] Epoch: 72, running loss: 0.269, current loss: 0.243 tau: 0.000: 100%|██████████| 20/20 [00:00<00:00, 22.63it/s]
# [Training] Epoch: 73, running loss: 0.269, current loss: 0.255, tau: -0.005: 100%|██████████| 207/207 [00:14<00:00, 14.56it/s]
# [Validation] Epoch: 73, running loss: 0.271, current loss: 0.240 tau: -0.003: 100%|██████████| 20/20 [00:00<00:00, 23.44it/s]
# [Training] Epoch: 74, running loss: 0.273, current loss: 0.258, tau: 0.008: 100%|██████████| 207/207 [00:14<00:00, 14.69it/s]
# [Validation] Epoch: 74, running loss: 0.310, current loss: 0.334 tau: -0.025: 100%|██████████| 20/20 [00:00<00:00, 22.75it/s]
# [Training] Epoch: 75, running loss: 0.268, current loss: 0.264, tau: 0.015: 100%|██████████| 207/207 [00:14<00:00, 14.61it/s]
# [Validation] Epoch: 75, running loss: 0.269, current loss: 0.233 tau: -0.020: 100%|██████████| 20/20 [00:00<00:00, 22.92it/s]
# [Training] Epoch: 76, running loss: 0.265, current loss: 0.255, tau: -0.011: 100%|██████████| 207/207 [00:13<00:00, 14.88it/s]
# [Validation] Epoch: 76, running loss: 0.274, current loss: 0.250 tau: 0.023: 100%|██████████| 20/20 [00:00<00:00, 23.35it/s]
# [Training] Epoch: 77, running loss: 0.264, current loss: 0.248, tau: 0.002: 100%|██████████| 207/207 [00:13<00:00, 14.82it/s]
# [Validation] Epoch: 77, running loss: 0.268, current loss: 0.243 tau: -0.012: 100%|██████████| 20/20 [00:00<00:00, 21.07it/s]
# [Training] Epoch: 78, running loss: 0.264, current loss: 0.265, tau: 0.009: 100%|██████████| 207/207 [00:14<00:00, 14.61it/s]
# [Validation] Epoch: 78, running loss: 0.276, current loss: 0.232 tau: 0.006: 100%|██████████| 20/20 [00:00<00:00, 22.54it/s]
# [Training] Epoch: 79, running loss: 0.265, current loss: 0.265, tau: -0.020: 100%|██████████| 207/207 [00:14<00:00, 14.61it/s]
# [Validation] Epoch: 79, running loss: 0.292, current loss: 0.273 tau: 0.041: 100%|██████████| 20/20 [00:00<00:00, 23.52it/s]
# [Training] Epoch: 80, running loss: 0.260, current loss: 0.253, tau: -0.017: 100%|██████████| 207/207 [00:14<00:00, 14.69it/s]
# [Validation] Epoch: 80, running loss: 0.282, current loss: 0.270 tau: 0.018: 100%|██████████| 20/20 [00:00<00:00, 23.82it/s]
# [Training] Epoch: 81, running loss: 0.259, current loss: 0.237, tau: 0.008: 100%|██████████| 207/207 [00:13<00:00, 14.79it/s]
# [Validation] Epoch: 81, running loss: 0.276, current loss: 0.253 tau: 0.036: 100%|██████████| 20/20 [00:00<00:00, 23.30it/s]
# [Training] Epoch: 82, running loss: 0.259, current loss: 0.248, tau: -0.023: 100%|██████████| 207/207 [00:14<00:00, 14.53it/s]
# [Validation] Epoch: 82, running loss: 0.268, current loss: 0.269 tau: 0.023: 100%|██████████| 20/20 [00:00<00:00, 23.74it/s]
# [Training] Epoch: 83, running loss: 0.258, current loss: 0.255, tau: -0.007: 100%|██████████| 207/207 [00:13<00:00, 14.79it/s]
# [Validation] Epoch: 83, running loss: 0.269, current loss: 0.245 tau: 0.041: 100%|██████████| 20/20 [00:00<00:00, 22.94it/s]
# [Training] Epoch: 84, running loss: 0.258, current loss: 0.251, tau: 0.021: 100%|██████████| 207/207 [00:14<00:00, 14.10it/s]
# [Validation] Epoch: 84, running loss: 0.276, current loss: 0.231 tau: 0.042: 100%|██████████| 20/20 [00:00<00:00, 23.53it/s]
# [Training] Epoch: 85, running loss: 0.258, current loss: 0.249, tau: -0.009: 100%|██████████| 207/207 [00:13<00:00, 14.81it/s]
# [Validation] Epoch: 85, running loss: 0.271, current loss: 0.246 tau: 0.028: 100%|██████████| 20/20 [00:00<00:00, 22.78it/s]
# [Training] Epoch: 86, running loss: 0.255, current loss: 0.265, tau: -0.036: 100%|██████████| 207/207 [00:14<00:00, 14.70it/s]
# [Validation] Epoch: 86, running loss: 0.262, current loss: 0.229 tau: 0.026: 100%|██████████| 20/20 [00:00<00:00, 23.78it/s]
# [Training] Epoch: 87, running loss: 0.256, current loss: 0.253, tau: -0.031: 100%|██████████| 207/207 [00:14<00:00, 14.58it/s]
# [Validation] Epoch: 87, running loss: 0.270, current loss: 0.230 tau: 0.002: 100%|██████████| 20/20 [00:00<00:00, 23.48it/s]
# [Training] Epoch: 88, running loss: 0.255, current loss: 0.247, tau: 0.003: 100%|██████████| 207/207 [00:14<00:00, 14.66it/s]
# [Validation] Epoch: 88, running loss: 0.257, current loss: 0.233 tau: 0.008: 100%|██████████| 20/20 [00:00<00:00, 24.52it/s]
# [Training] Epoch: 89, running loss: 0.253, current loss: 0.239, tau: -0.021: 100%|██████████| 207/207 [00:14<00:00, 14.65it/s]
# [Validation] Epoch: 89, running loss: 0.263, current loss: 0.230 tau: -0.001: 100%|██████████| 20/20 [00:00<00:00, 23.93it/s]
# [Training] Epoch: 90, running loss: 0.253, current loss: 0.234, tau: 0.017: 100%|██████████| 207/207 [00:14<00:00, 14.59it/s]
# [Validation] Epoch: 90, running loss: 0.266, current loss: 0.238 tau: 0.007: 100%|██████████| 20/20 [00:00<00:00, 23.09it/s]
# [Training] Epoch: 91, running loss: 0.253, current loss: 0.258, tau: -0.021: 100%|██████████| 207/207 [00:14<00:00, 14.67it/s]
# [Validation] Epoch: 91, running loss: 0.258, current loss: 0.222 tau: -0.003: 100%|██████████| 20/20 [00:00<00:00, 23.19it/s]
# [Training] Epoch: 92, running loss: 0.251, current loss: 0.239, tau: -0.028: 100%|██████████| 207/207 [00:13<00:00, 14.82it/s]
# [Validation] Epoch: 92, running loss: 0.268, current loss: 0.228 tau: 0.010: 100%|██████████| 20/20 [00:00<00:00, 23.20it/s]
# [Training] Epoch: 93, running loss: 0.251, current loss: 0.233, tau: 0.059: 100%|██████████| 207/207 [00:13<00:00, 14.90it/s]
# [Validation] Epoch: 93, running loss: 0.261, current loss: 0.222 tau: -0.001: 100%|██████████| 20/20 [00:01<00:00, 19.40it/s]
# [Training] Epoch: 94, running loss: 0.252, current loss: 0.235, tau: -0.017: 100%|██████████| 207/207 [00:14<00:00, 14.70it/s]
# [Validation] Epoch: 94, running loss: 0.258, current loss: 0.219 tau: 0.010: 100%|██████████| 20/20 [00:00<00:00, 22.98it/s]
# [Training] Epoch: 95, running loss: 0.249, current loss: 0.241, tau: -0.030: 100%|██████████| 207/207 [00:13<00:00, 14.84it/s]
# [Validation] Epoch: 95, running loss: 0.261, current loss: 0.224 tau: -0.010: 100%|██████████| 20/20 [00:00<00:00, 23.01it/s]
# [Training] Epoch: 96, running loss: 0.250, current loss: 0.246, tau: 0.024: 100%|██████████| 207/207 [00:14<00:00, 14.67it/s]
# [Validation] Epoch: 96, running loss: 0.259, current loss: 0.223 tau: 0.025: 100%|██████████| 20/20 [00:00<00:00, 22.95it/s]
# [Training] Epoch: 97, running loss: 0.248, current loss: 0.251, tau: 0.020: 100%|██████████| 207/207 [00:13<00:00, 14.92it/s]
# [Validation] Epoch: 97, running loss: 0.258, current loss: 0.233 tau: -0.013: 100%|██████████| 20/20 [00:00<00:00, 22.94it/s]
# [Training] Epoch: 98, running loss: 0.247, current loss: 0.242, tau: 0.039: 100%|██████████| 207/207 [00:14<00:00, 14.50it/s]
# [Validation] Epoch: 98, running loss: 0.252, current loss: 0.226 tau: -0.019: 100%|██████████| 20/20 [00:01<00:00, 19.95it/s]
# [Training] Epoch: 99, running loss: 0.248, current loss: 0.247, tau: -0.010: 100%|██████████| 207/207 [00:14<00:00, 14.74it/s]
# [Validation] Epoch: 99, running loss: 0.254, current loss: 0.221 tau: -0.008: 100%|██████████| 20/20 [00:00<00:00, 22.47it/s]
# [Training] Epoch: 100, running loss: 0.246, current loss: 0.239, tau: -0.001: 100%|██████████| 207/207 [00:14<00:00, 14.57it/s]
# [Validation] Epoch: 100, running loss: 0.255, current loss: 0.230 tau: 0.015: 100%|██████████| 20/20 [00:00<00:00, 23.40it/s]
# [Training] Epoch: 101, running loss: 0.246, current loss: 0.251, tau: -0.001: 100%|██████████| 207/207 [00:13<00:00, 14.79it/s]
# [Validation] Epoch: 101, running loss: 0.259, current loss: 0.238 tau: -0.006: 100%|██████████| 20/20 [00:00<00:00, 22.94it/s]
# [Training] Epoch: 102, running loss: 0.245, current loss: 0.234, tau: 0.001: 100%|██████████| 207/207 [00:13<00:00, 14.83it/s]
# [Validation] Epoch: 102, running loss: 0.258, current loss: 0.232 tau: 0.007: 100%|██████████| 20/20 [00:00<00:00, 23.38it/s]
# [Training] Epoch: 103, running loss: 0.244, current loss: 0.241, tau: -0.002: 100%|██████████| 207/207 [00:14<00:00, 14.55it/s]
# [Validation] Epoch: 103, running loss: 0.261, current loss: 0.220 tau: 0.008: 100%|██████████| 20/20 [00:00<00:00, 24.04it/s]
# [Training] Epoch: 104, running loss: 0.244, current loss: 0.234, tau: -0.030: 100%|██████████| 207/207 [00:13<00:00, 14.79it/s]
# [Validation] Epoch: 104, running loss: 0.260, current loss: 0.247 tau: -0.013: 100%|██████████| 20/20 [00:00<00:00, 24.11it/s]
# [Training] Epoch: 105, running loss: 0.243, current loss: 0.240, tau: 0.000: 100%|██████████| 207/207 [00:14<00:00, 14.67it/s]
# [Validation] Epoch: 105, running loss: 0.256, current loss: 0.229 tau: 0.014: 100%|██████████| 20/20 [00:00<00:00, 23.38it/s]
# [Training] Epoch: 106, running loss: 0.242, current loss: 0.244, tau: 0.031: 100%|██████████| 207/207 [00:13<00:00, 14.99it/s]
# [Validation] Epoch: 106, running loss: 0.257, current loss: 0.253 tau: 0.004: 100%|██████████| 20/20 [00:00<00:00, 23.12it/s]
# [Training] Epoch: 107, running loss: 0.242, current loss: 0.233, tau: 0.006: 100%|██████████| 207/207 [00:14<00:00, 14.60it/s]
# [Validation] Epoch: 107, running loss: 0.255, current loss: 0.230 tau: 0.039: 100%|██████████| 20/20 [00:00<00:00, 22.24it/s]
# [Training] Epoch: 108, running loss: 0.240, current loss: 0.236, tau: -0.023: 100%|██████████| 207/207 [00:13<00:00, 15.02it/s]
# [Validation] Epoch: 108, running loss: 0.253, current loss: 0.228 tau: 0.023: 100%|██████████| 20/20 [00:00<00:00, 23.73it/s]
# [Training] Epoch: 109, running loss: 0.240, current loss: 0.236, tau: 0.022: 100%|██████████| 207/207 [00:13<00:00, 14.93it/s]
# [Validation] Epoch: 109, running loss: 0.255, current loss: 0.234 tau: -0.000: 100%|██████████| 20/20 [00:00<00:00, 20.78it/s]
# [Training] Epoch: 110, running loss: 0.240, current loss: 0.230, tau: 0.022: 100%|██████████| 207/207 [00:13<00:00, 14.89it/s]
# [Validation] Epoch: 110, running loss: 0.253, current loss: 0.228 tau: -0.036: 100%|██████████| 20/20 [00:00<00:00, 23.52it/s]
# [Training] Epoch: 111, running loss: 0.239, current loss: 0.229, tau: -0.013: 100%|██████████| 207/207 [00:13<00:00, 14.83it/s]
# [Validation] Epoch: 111, running loss: 0.254, current loss: 0.231 tau: 0.025: 100%|██████████| 20/20 [00:00<00:00, 23.84it/s]
# [Training] Epoch: 112, running loss: 0.239, current loss: 0.233, tau: 0.027: 100%|██████████| 207/207 [00:13<00:00, 14.97it/s]
# [Validation] Epoch: 112, running loss: 0.253, current loss: 0.232 tau: -0.004: 100%|██████████| 20/20 [00:00<00:00, 22.42it/s]
# [Training] Epoch: 113, running loss: 0.238, current loss: 0.221, tau: -0.025: 100%|██████████| 207/207 [00:13<00:00, 15.19it/s]
# [Validation] Epoch: 113, running loss: 0.251, current loss: 0.224 tau: -0.001: 100%|██████████| 20/20 [00:00<00:00, 22.03it/s]
# [Training] Epoch: 114, running loss: 0.237, current loss: 0.232, tau: 0.023: 100%|██████████| 207/207 [00:14<00:00, 14.70it/s]
# [Validation] Epoch: 114, running loss: 0.252, current loss: 0.240 tau: 0.003: 100%|██████████| 20/20 [00:00<00:00, 21.79it/s]
# [Training] Epoch: 115, running loss: 0.237, current loss: 0.225, tau: 0.054: 100%|██████████| 207/207 [00:13<00:00, 14.92it/s]
# [Validation] Epoch: 115, running loss: 0.248, current loss: 0.231 tau: 0.033: 100%|██████████| 20/20 [00:00<00:00, 24.47it/s]
# [Training] Epoch: 116, running loss: 0.237, current loss: 0.225, tau: 0.019: 100%|██████████| 207/207 [00:13<00:00, 14.80it/s]
# [Validation] Epoch: 116, running loss: 0.252, current loss: 0.242 tau: -0.017: 100%|██████████| 20/20 [00:00<00:00, 23.77it/s]
# [Training] Epoch: 117, running loss: 0.236, current loss: 0.229, tau: 0.009: 100%|██████████| 207/207 [00:13<00:00, 15.13it/s]
# [Validation] Epoch: 117, running loss: 0.251, current loss: 0.231 tau: 0.061: 100%|██████████| 20/20 [00:00<00:00, 22.97it/s]
# [Training] Epoch: 118, running loss: 0.236, current loss: 0.222, tau: -0.034: 100%|██████████| 207/207 [00:13<00:00, 14.91it/s]
# [Validation] Epoch: 118, running loss: 0.253, current loss: 0.244 tau: 0.012: 100%|██████████| 20/20 [00:00<00:00, 24.15it/s]
# [Training] Epoch: 119, running loss: 0.236, current loss: 0.222, tau: -0.027: 100%|██████████| 207/207 [00:13<00:00, 14.99it/s]
# [Validation] Epoch: 119, running loss: 0.245, current loss: 0.223 tau: -0.006: 100%|██████████| 20/20 [00:00<00:00, 24.27it/s]
# [Training] Epoch: 120, running loss: 0.234, current loss: 0.227, tau: 0.000: 100%|██████████| 207/207 [00:13<00:00, 15.00it/s]
# [Validation] Epoch: 120, running loss: 0.248, current loss: 0.236 tau: 0.029: 100%|██████████| 20/20 [00:00<00:00, 24.24it/s]
# [Training] Epoch: 121, running loss: 0.235, current loss: 0.219, tau: 0.004: 100%|██████████| 207/207 [00:13<00:00, 14.96it/s]
# [Validation] Epoch: 121, running loss: 0.245, current loss: 0.226 tau: 0.005: 100%|██████████| 20/20 [00:00<00:00, 24.23it/s]
# [Training] Epoch: 122, running loss: 0.234, current loss: 0.229, tau: 0.010: 100%|██████████| 207/207 [00:14<00:00, 14.61it/s]
# [Validation] Epoch: 122, running loss: 0.245, current loss: 0.230 tau: -0.004: 100%|██████████| 20/20 [00:00<00:00, 23.82it/s]
# [Training] Epoch: 123, running loss: 0.234, current loss: 0.224, tau: 0.008: 100%|██████████| 207/207 [00:14<00:00, 14.67it/s]
# [Validation] Epoch: 123, running loss: 0.242, current loss: 0.227 tau: -0.013: 100%|██████████| 20/20 [00:00<00:00, 22.41it/s]
# [Training] Epoch: 124, running loss: 0.233, current loss: 0.225, tau: 0.018: 100%|██████████| 207/207 [00:14<00:00, 14.57it/s]
# [Validation] Epoch: 124, running loss: 0.247, current loss: 0.238 tau: -0.013: 100%|██████████| 20/20 [00:00<00:00, 24.22it/s]
# [Training] Epoch: 125, running loss: 0.233, current loss: 0.233, tau: 0.025: 100%|██████████| 207/207 [00:13<00:00, 15.09it/s]
# [Validation] Epoch: 125, running loss: 0.245, current loss: 0.230 tau: 0.010: 100%|██████████| 20/20 [00:00<00:00, 20.19it/s]
# [Training] Epoch: 126, running loss: 0.233, current loss: 0.231, tau: 0.032: 100%|██████████| 207/207 [00:13<00:00, 14.90it/s]
# [Validation] Epoch: 126, running loss: 0.248, current loss: 0.234 tau: -0.029: 100%|██████████| 20/20 [00:00<00:00, 23.60it/s]
# [Training] Epoch: 127, running loss: 0.233, current loss: 0.226, tau: -0.026: 100%|██████████| 207/207 [00:13<00:00, 14.79it/s]
# [Validation] Epoch: 127, running loss: 0.244, current loss: 0.230 tau: 0.024: 100%|██████████| 20/20 [00:00<00:00, 23.20it/s]
# [Training] Epoch: 128, running loss: 0.232, current loss: 0.225, tau: 0.001: 100%|██████████| 207/207 [00:14<00:00, 14.68it/s]
# [Validation] Epoch: 128, running loss: 0.246, current loss: 0.225 tau: -0.004: 100%|██████████| 20/20 [00:00<00:00, 23.56it/s]
# [Training] Epoch: 129, running loss: 0.232, current loss: 0.229, tau: 0.013: 100%|██████████| 207/207 [00:13<00:00, 14.83it/s]
# [Validation] Epoch: 129, running loss: 0.246, current loss: 0.224 tau: 0.014: 100%|██████████| 20/20 [00:00<00:00, 24.02it/s]
# [Training] Epoch: 130, running loss: 0.231, current loss: 0.234, tau: -0.029: 100%|██████████| 207/207 [00:13<00:00, 14.80it/s]
# [Validation] Epoch: 130, running loss: 0.247, current loss: 0.226 tau: 0.023: 100%|██████████| 20/20 [00:00<00:00, 23.49it/s]
# [Training] Epoch: 131, running loss: 0.231, current loss: 0.231, tau: -0.049: 100%|██████████| 207/207 [00:13<00:00, 15.13it/s]
# [Validation] Epoch: 131, running loss: 0.246, current loss: 0.220 tau: -0.001: 100%|██████████| 20/20 [00:00<00:00, 23.79it/s]
# [Training] Epoch: 132, running loss: 0.231, current loss: 0.226, tau: 0.016: 100%|██████████| 207/207 [00:14<00:00, 14.69it/s]
# [Validation] Epoch: 132, running loss: 0.242, current loss: 0.222 tau: 0.014: 100%|██████████| 20/20 [00:00<00:00, 23.51it/s]
# [Training] Epoch: 133, running loss: 0.230, current loss: 0.225, tau: -0.022: 100%|██████████| 207/207 [00:14<00:00, 14.58it/s]
# [Validation] Epoch: 133, running loss: 0.241, current loss: 0.217 tau: -0.013: 100%|██████████| 20/20 [00:00<00:00, 24.30it/s]
# [Training] Epoch: 134, running loss: 0.230, current loss: 0.236, tau: 0.005: 100%|██████████| 207/207 [00:13<00:00, 15.09it/s]
# [Validation] Epoch: 134, running loss: 0.242, current loss: 0.223 tau: 0.004: 100%|██████████| 20/20 [00:00<00:00, 20.25it/s]
# [Training] Epoch: 135, running loss: 0.230, current loss: 0.228, tau: 0.007: 100%|██████████| 207/207 [00:13<00:00, 14.82it/s]
# [Validation] Epoch: 135, running loss: 0.238, current loss: 0.217 tau: -0.000: 100%|██████████| 20/20 [00:00<00:00, 24.10it/s]
# [Training] Epoch: 136, running loss: 0.229, current loss: 0.230, tau: 0.012: 100%|██████████| 207/207 [00:13<00:00, 15.00it/s]
# [Validation] Epoch: 136, running loss: 0.238, current loss: 0.222 tau: -0.016: 100%|██████████| 20/20 [00:00<00:00, 23.48it/s]
# [Training] Epoch: 137, running loss: 0.229, current loss: 0.234, tau: -0.008: 100%|██████████| 207/207 [00:13<00:00, 14.94it/s]
# [Validation] Epoch: 137, running loss: 0.240, current loss: 0.217 tau: 0.007: 100%|██████████| 20/20 [00:00<00:00, 22.51it/s]
# [Training] Epoch: 138, running loss: 0.229, current loss: 0.229, tau: 0.010: 100%|██████████| 207/207 [00:13<00:00, 15.01it/s]
# [Validation] Epoch: 138, running loss: 0.243, current loss: 0.221 tau: 0.004: 100%|██████████| 20/20 [00:00<00:00, 23.77it/s]
# [Training] Epoch: 139, running loss: 0.228, current loss: 0.229, tau: 0.024: 100%|██████████| 207/207 [00:13<00:00, 14.84it/s]
# [Validation] Epoch: 139, running loss: 0.240, current loss: 0.218 tau: 0.022: 100%|██████████| 20/20 [00:00<00:00, 23.38it/s]
# [Training] Epoch: 140, running loss: 0.228, current loss: 0.229, tau: -0.016: 100%|██████████| 207/207 [00:14<00:00, 14.75it/s]
# [Validation] Epoch: 140, running loss: 0.241, current loss: 0.218 tau: -0.009: 100%|██████████| 20/20 [00:00<00:00, 22.39it/s]
# [Training] Epoch: 141, running loss: 0.228, current loss: 0.234, tau: 0.013: 100%|██████████| 207/207 [00:13<00:00, 14.88it/s]
# [Validation] Epoch: 141, running loss: 0.239, current loss: 0.217 tau: 0.033: 100%|██████████| 20/20 [00:00<00:00, 22.15it/s]
# [Training] Epoch: 142, running loss: 0.227, current loss: 0.229, tau: 0.009: 100%|██████████| 207/207 [00:14<00:00, 14.72it/s]
# [Validation] Epoch: 142, running loss: 0.238, current loss: 0.217 tau: 0.005: 100%|██████████| 20/20 [00:00<00:00, 24.21it/s]
# [Training] Epoch: 143, running loss: 0.227, current loss: 0.229, tau: 0.002: 100%|██████████| 207/207 [00:13<00:00, 14.87it/s]
# [Validation] Epoch: 143, running loss: 0.238, current loss: 0.214 tau: -0.003: 100%|██████████| 20/20 [00:00<00:00, 24.37it/s]
# [Training] Epoch: 144, running loss: 0.227, current loss: 0.229, tau: -0.007: 100%|██████████| 207/207 [00:14<00:00, 14.71it/s]
# [Validation] Epoch: 144, running loss: 0.238, current loss: 0.212 tau: 0.000: 100%|██████████| 20/20 [00:00<00:00, 23.52it/s]
# [Training] Epoch: 145, running loss: 0.227, current loss: 0.227, tau: 0.006: 100%|██████████| 207/207 [00:13<00:00, 15.03it/s]
# [Validation] Epoch: 145, running loss: 0.237, current loss: 0.214 tau: -0.010: 100%|██████████| 20/20 [00:00<00:00, 24.48it/s]
# [Training] Epoch: 146, running loss: 0.226, current loss: 0.228, tau: -0.046: 100%|██████████| 207/207 [00:14<00:00, 14.70it/s]
# [Validation] Epoch: 146, running loss: 0.236, current loss: 0.212 tau: -0.016: 100%|██████████| 20/20 [00:00<00:00, 23.93it/s]
# [Training] Epoch: 147, running loss: 0.226, current loss: 0.227, tau: -0.030: 100%|██████████| 207/207 [00:13<00:00, 15.03it/s]
# [Validation] Epoch: 147, running loss: 0.237, current loss: 0.213 tau: -0.015: 100%|██████████| 20/20 [00:00<00:00, 23.94it/s]
# [Training] Epoch: 148, running loss: 0.226, current loss: 0.227, tau: -0.036: 100%|██████████| 207/207 [00:13<00:00, 14.90it/s]
# [Validation] Epoch: 148, running loss: 0.237, current loss: 0.212 tau: -0.008: 100%|██████████| 20/20 [00:00<00:00, 22.12it/s]
# [Training] Epoch: 149, running loss: 0.226, current loss: 0.228, tau: -0.027: 100%|██████████| 207/207 [00:13<00:00, 14.92it/s]
# [Validation] Epoch: 149, running loss: 0.237, current loss: 0.212 tau: -0.011: 100%|██████████| 20/20 [00:00<00:00, 24.23it/s]
# [Training] Epoch: 150, running loss: 0.225, current loss: 0.227, tau: 0.021: 100%|██████████| 207/207 [00:13<00:00, 15.03it/s]
# [Validation] Epoch: 150, running loss: 0.237, current loss: 0.212 tau: 0.017: 100%|██████████| 20/20 [00:00<00:00, 20.82it/s]
# [Training] Epoch: 151, running loss: 0.225, current loss: 0.229, tau: 0.022: 100%|██████████| 207/207 [00:13<00:00, 14.99it/s]
# [Validation] Epoch: 151, running loss: 0.236, current loss: 0.211 tau: -0.020: 100%|██████████| 20/20 [00:00<00:00, 24.25it/s]
# [Training] Epoch: 152, running loss: 0.225, current loss: 0.230, tau: -0.020: 100%|██████████| 207/207 [00:13<00:00, 15.01it/s]
# [Validation] Epoch: 152, running loss: 0.236, current loss: 0.210 tau: -0.004: 100%|██████████| 20/20 [00:00<00:00, 24.42it/s]
# [Training] Epoch: 153, running loss: 0.225, current loss: 0.228, tau: 0.010: 100%|██████████| 207/207 [00:13<00:00, 14.88it/s]
# [Validation] Epoch: 153, running loss: 0.235, current loss: 0.210 tau: -0.004: 100%|██████████| 20/20 [00:00<00:00, 24.17it/s]
# [Training] Epoch: 154, running loss: 0.225, current loss: 0.226, tau: -0.010: 100%|██████████| 207/207 [00:13<00:00, 14.99it/s]
# [Validation] Epoch: 154, running loss: 0.235, current loss: 0.210 tau: -0.015: 100%|██████████| 20/20 [00:00<00:00, 24.29it/s]
# [Training] Epoch: 155, running loss: 0.224, current loss: 0.225, tau: 0.028: 100%|██████████| 207/207 [00:14<00:00, 14.77it/s]
# [Validation] Epoch: 155, running loss: 0.234, current loss: 0.210 tau: -0.030: 100%|██████████| 20/20 [00:00<00:00, 24.07it/s]
# [Training] Epoch: 156, running loss: 0.224, current loss: 0.223, tau: 0.013: 100%|██████████| 207/207 [00:13<00:00, 15.14it/s]
# [Validation] Epoch: 156, running loss: 0.233, current loss: 0.210 tau: -0.037: 100%|██████████| 20/20 [00:00<00:00, 23.96it/s]
# [Training] Epoch: 157, running loss: 0.223, current loss: 0.222, tau: 0.012: 100%|██████████| 207/207 [00:14<00:00, 14.63it/s]
# [Validation] Epoch: 157, running loss: 0.232, current loss: 0.210 tau: 0.023: 100%|██████████| 20/20 [00:00<00:00, 24.53it/s]
# [Training] Epoch: 158, running loss: 0.223, current loss: 0.221, tau: 0.013: 100%|██████████| 207/207 [00:13<00:00, 15.16it/s]
# [Validation] Epoch: 158, running loss: 0.232, current loss: 0.210 tau: 0.039: 100%|██████████| 20/20 [00:00<00:00, 23.63it/s]
# [Training] Epoch: 159, running loss: 0.222, current loss: 0.221, tau: 0.019: 100%|██████████| 207/207 [00:13<00:00, 15.00it/s]
# [Validation] Epoch: 159, running loss: 0.231, current loss: 0.209 tau: 0.025: 100%|██████████| 20/20 [00:00<00:00, 22.30it/s]
# [Training] Epoch: 160, running loss: 0.222, current loss: 0.220, tau: -0.025: 100%|██████████| 207/207 [00:14<00:00, 14.69it/s]
# [Validation] Epoch: 160, running loss: 0.231, current loss: 0.209 tau: 0.012: 100%|██████████| 20/20 [00:00<00:00, 23.53it/s]
# [Training] Epoch: 161, running loss: 0.221, current loss: 0.221, tau: 0.018: 100%|██████████| 207/207 [00:13<00:00, 15.06it/s]
# [Validation] Epoch: 161, running loss: 0.231, current loss: 0.210 tau: 0.005: 100%|██████████| 20/20 [00:00<00:00, 22.45it/s]
# [Training] Epoch: 162, running loss: 0.221, current loss: 0.220, tau: 0.007: 100%|██████████| 207/207 [00:14<00:00, 14.62it/s]
# [Validation] Epoch: 162, running loss: 0.230, current loss: 0.210 tau: 0.015: 100%|██████████| 20/20 [00:00<00:00, 23.47it/s]
# [Training] Epoch: 163, running loss: 0.221, current loss: 0.220, tau: 0.008: 100%|██████████| 207/207 [00:13<00:00, 14.99it/s]
# [Validation] Epoch: 163, running loss: 0.229, current loss: 0.210 tau: -0.010: 100%|██████████| 20/20 [00:00<00:00, 23.76it/s]
# [Training] Epoch: 164, running loss: 0.220, current loss: 0.219, tau: -0.009: 100%|██████████| 207/207 [00:13<00:00, 14.82it/s]
# [Validation] Epoch: 164, running loss: 0.229, current loss: 0.210 tau: 0.026: 100%|██████████| 20/20 [00:00<00:00, 23.84it/s]
# [Training] Epoch: 165, running loss: 0.220, current loss: 0.219, tau: 0.018: 100%|██████████| 207/207 [00:13<00:00, 15.09it/s]
# [Validation] Epoch: 165, running loss: 0.228, current loss: 0.210 tau: -0.001: 100%|██████████| 20/20 [00:00<00:00, 24.15it/s]
# [Training] Epoch: 166, running loss: 0.220, current loss: 0.219, tau: 0.004: 100%|██████████| 207/207 [00:14<00:00, 14.62it/s]
# [Validation] Epoch: 166, running loss: 0.228, current loss: 0.210 tau: 0.008: 100%|██████████| 20/20 [00:00<00:00, 24.22it/s]
# [Training] Epoch: 167, running loss: 0.219, current loss: 0.218, tau: 0.001: 100%|██████████| 207/207 [00:13<00:00, 15.03it/s]
# [Validation] Epoch: 167, running loss: 0.227, current loss: 0.211 tau: -0.008: 100%|██████████| 20/20 [00:00<00:00, 24.15it/s]
# [Training] Epoch: 168, running loss: 0.219, current loss: 0.218, tau: -0.023: 100%|██████████| 207/207 [00:13<00:00, 14.96it/s]
# [Validation] Epoch: 168, running loss: 0.227, current loss: 0.211 tau: 0.010: 100%|██████████| 20/20 [00:00<00:00, 22.00it/s]
# [Training] Epoch: 169, running loss: 0.219, current loss: 0.218, tau: -0.001: 100%|██████████| 207/207 [00:13<00:00, 14.82it/s]
# [Validation] Epoch: 169, running loss: 0.227, current loss: 0.211 tau: 0.019: 100%|██████████| 20/20 [00:00<00:00, 23.62it/s]
# [Training] Epoch: 170, running loss: 0.219, current loss: 0.218, tau: -0.001: 100%|██████████| 207/207 [00:13<00:00, 14.83it/s]
# [Validation] Epoch: 170, running loss: 0.227, current loss: 0.211 tau: -0.011: 100%|██████████| 20/20 [00:00<00:00, 23.00it/s]
# [Training] Epoch: 171, running loss: 0.218, current loss: 0.218, tau: -0.017: 100%|██████████| 207/207 [00:14<00:00, 14.38it/s]
# [Validation] Epoch: 171, running loss: 0.227, current loss: 0.212 tau: 0.018: 100%|██████████| 20/20 [00:00<00:00, 24.44it/s]
# [Training] Epoch: 172, running loss: 0.218, current loss: 0.218, tau: -0.003: 100%|██████████| 207/207 [00:13<00:00, 14.97it/s]
# [Validation] Epoch: 172, running loss: 0.227, current loss: 0.212 tau: 0.028: 100%|██████████| 20/20 [00:00<00:00, 24.12it/s]
# [Training] Epoch: 173, running loss: 0.218, current loss: 0.218, tau: 0.006: 100%|██████████| 207/207 [00:14<00:00, 14.54it/s]
# [Validation] Epoch: 173, running loss: 0.227, current loss: 0.212 tau: 0.032: 100%|██████████| 20/20 [00:00<00:00, 24.00it/s]
# [Training] Epoch: 174, running loss: 0.217, current loss: 0.217, tau: 0.002: 100%|██████████| 207/207 [00:13<00:00, 15.13it/s]
# [Validation] Epoch: 174, running loss: 0.227, current loss: 0.212 tau: 0.052: 100%|██████████| 20/20 [00:00<00:00, 23.28it/s]
# [Training] Epoch: 175, running loss: 0.217, current loss: 0.217, tau: 0.006: 100%|██████████| 207/207 [00:13<00:00, 14.87it/s]
# [Validation] Epoch: 175, running loss: 0.227, current loss: 0.212 tau: 0.032: 100%|██████████| 20/20 [00:01<00:00, 19.66it/s]
# [Training] Epoch: 176, running loss: 0.217, current loss: 0.217, tau: -0.031: 100%|██████████| 207/207 [00:13<00:00, 15.15it/s]
# [Validation] Epoch: 176, running loss: 0.227, current loss: 0.212 tau: 0.014: 100%|██████████| 20/20 [00:00<00:00, 24.55it/s]
# [Training] Epoch: 177, running loss: 0.217, current loss: 0.216, tau: -0.038: 100%|██████████| 207/207 [00:13<00:00, 14.93it/s]
# [Validation] Epoch: 177, running loss: 0.227, current loss: 0.213 tau: 0.018: 100%|██████████| 20/20 [00:00<00:00, 23.32it/s]
# [Training] Epoch: 178, running loss: 0.217, current loss: 0.215, tau: -0.028: 100%|██████████| 207/207 [00:14<00:00, 14.78it/s]
# [Validation] Epoch: 178, running loss: 0.227, current loss: 0.213 tau: 0.019: 100%|██████████| 20/20 [00:00<00:00, 23.40it/s]
# [Training] Epoch: 179, running loss: 0.217, current loss: 0.215, tau: -0.028: 100%|██████████| 207/207 [00:13<00:00, 15.04it/s]
# [Validation] Epoch: 179, running loss: 0.227, current loss: 0.213 tau: 0.028: 100%|██████████| 20/20 [00:00<00:00, 23.64it/s]
# [Training] Epoch: 180, running loss: 0.216, current loss: 0.214, tau: -0.001: 100%|██████████| 207/207 [00:13<00:00, 14.92it/s]
# [Validation] Epoch: 180, running loss: 0.226, current loss: 0.213 tau: 0.027: 100%|██████████| 20/20 [00:00<00:00, 24.42it/s]
# [Training] Epoch: 181, running loss: 0.216, current loss: 0.213, tau: 0.032: 100%|██████████| 207/207 [00:13<00:00, 15.13it/s]
# [Validation] Epoch: 181, running loss: 0.226, current loss: 0.213 tau: 0.029: 100%|██████████| 20/20 [00:00<00:00, 23.46it/s]
# [Training] Epoch: 182, running loss: 0.216, current loss: 0.213, tau: 0.007: 100%|██████████| 207/207 [00:14<00:00, 14.76it/s]
# [Validation] Epoch: 182, running loss: 0.226, current loss: 0.213 tau: 0.027: 100%|██████████| 20/20 [00:00<00:00, 24.30it/s]
# [Training] Epoch: 183, running loss: 0.216, current loss: 0.212, tau: 0.015: 100%|██████████| 207/207 [00:13<00:00, 15.01it/s]
# [Validation] Epoch: 183, running loss: 0.226, current loss: 0.213 tau: 0.022: 100%|██████████| 20/20 [00:00<00:00, 22.84it/s]
# [Training] Epoch: 184, running loss: 0.216, current loss: 0.211, tau: 0.002: 100%|██████████| 207/207 [00:13<00:00, 14.97it/s]
# [Validation] Epoch: 184, running loss: 0.226, current loss: 0.213 tau: 0.032: 100%|██████████| 20/20 [00:00<00:00, 23.99it/s]
# [Training] Epoch: 185, running loss: 0.216, current loss: 0.211, tau: 0.015: 100%|██████████| 207/207 [00:13<00:00, 14.84it/s]
# [Validation] Epoch: 185, running loss: 0.226, current loss: 0.213 tau: 0.033: 100%|██████████| 20/20 [00:00<00:00, 24.26it/s]
# [Training] Epoch: 186, running loss: 0.216, current loss: 0.210, tau: -0.006: 100%|██████████| 207/207 [00:13<00:00, 15.09it/s]
# [Validation] Epoch: 186, running loss: 0.226, current loss: 0.213 tau: 0.027: 100%|██████████| 20/20 [00:00<00:00, 21.86it/s]
# [Training] Epoch: 187, running loss: 0.215, current loss: 0.210, tau: -0.002: 100%|██████████| 207/207 [00:13<00:00, 14.94it/s]
# [Validation] Epoch: 187, running loss: 0.226, current loss: 0.213 tau: -0.001: 100%|██████████| 20/20 [00:00<00:00, 22.55it/s]
# [Training] Epoch: 188, running loss: 0.215, current loss: 0.209, tau: -0.018: 100%|██████████| 207/207 [00:13<00:00, 15.05it/s]
# ...
# [Validation] Epoch: 136, running loss: 0.811, current loss: 1.304 tau: -0.059: 100%|██████████| 7/7 [00:00<00:00,  7.04it/s]
# [Training] Epoch: 137, running loss: 0.454, current loss: 0.379, tau: 0.067: 100%|██████████| 61/61 [00:11<00:00,  5.28it/s]
# [Validation] Epoch: 137, running loss: 0.806, current loss: 1.307 tau: -0.036: 100%|██████████| 7/7 [00:00<00:00,  9.55it/s]
# [Training] Epoch: 138, running loss: 0.453, current loss: 0.376, tau: 0.063: 100%|██████████| 61/61 [00:10<00:00,  5.69it/s]
# [Validation] Epoch: 138, running loss: 0.804, current loss: 1.278 tau: -0.002: 100%|██████████| 7/7 [00:00<00:00,  9.59it/s]
# [Training] Epoch: 139, running loss: 0.455, current loss: 0.373, tau: 0.073: 100%|██████████| 61/61 [00:10<00:00,  5.70it/s]
# [Validation] Epoch: 139, running loss: 0.817, current loss: 1.333 tau: -0.018: 100%|██████████| 7/7 [00:00<00:00,  9.56it/s]
# [Training] Epoch: 140, running loss: 0.453, current loss: 0.374, tau: 0.103: 100%|██████████| 61/61 [00:10<00:00,  5.70it/s]
# [Validation] Epoch: 140, running loss: 0.801, current loss: 1.276 tau: -0.033: 100%|██████████| 7/7 [00:00<00:00,  9.56it/s]
# [Training] Epoch: 141, running loss: 0.453, current loss: 0.372, tau: 0.007: 100%|██████████| 61/61 [00:10<00:00,  5.64it/s]
# [Validation] Epoch: 141, running loss: 0.815, current loss: 1.383 tau: 0.011: 100%|██████████| 7/7 [00:00<00:00,  9.51it/s]
# [Training] Epoch: 142, running loss: 0.450, current loss: 0.370, tau: 0.054: 100%|██████████| 61/61 [00:10<00:00,  5.59it/s]
# [Validation] Epoch: 142, running loss: 0.811, current loss: 1.287 tau: 0.001: 100%|██████████| 7/7 [00:00<00:00,  8.96it/s]
# [Training] Epoch: 143, running loss: 0.450, current loss: 0.371, tau: 0.085: 100%|██████████| 61/61 [00:10<00:00,  5.60it/s]
# [Validation] Epoch: 143, running loss: 0.816, current loss: 1.360 tau: -0.032: 100%|██████████| 7/7 [00:00<00:00,  9.75it/s]
# [Training] Epoch: 144, running loss: 0.450, current loss: 0.374, tau: 0.064: 100%|██████████| 61/61 [00:10<00:00,  5.73it/s]
# [Validation] Epoch: 144, running loss: 0.811, current loss: 1.324 tau: -0.002: 100%|██████████| 7/7 [00:00<00:00,  9.76it/s]
# [Training] Epoch: 145, running loss: 0.448, current loss: 0.368, tau: 0.072: 100%|██████████| 61/61 [00:10<00:00,  5.60it/s]
# [Validation] Epoch: 145, running loss: 0.811, current loss: 1.328 tau: -0.039: 100%|██████████| 7/7 [00:00<00:00,  9.47it/s]
# [Training] Epoch: 146, running loss: 0.448, current loss: 0.369, tau: 0.061: 100%|██████████| 61/61 [00:10<00:00,  5.71it/s]
# [Validation] Epoch: 146, running loss: 0.813, current loss: 1.362 tau: -0.029: 100%|██████████| 7/7 [00:00<00:00,  9.69it/s]
# [Training] Epoch: 147, running loss: 0.447, current loss: 0.369, tau: 0.055: 100%|██████████| 61/61 [00:10<00:00,  5.70it/s]
# [Validation] Epoch: 147, running loss: 0.820, current loss: 1.359 tau: -0.061: 100%|██████████| 7/7 [00:00<00:00,  9.79it/s]
# [Training] Epoch: 148, running loss: 0.447, current loss: 0.367, tau: 0.074: 100%|██████████| 61/61 [00:10<00:00,  5.60it/s]
# [Validation] Epoch: 148, running loss: 0.825, current loss: 1.400 tau: 0.029: 100%|██████████| 7/7 [00:00<00:00,  8.66it/s]
# [Training] Epoch: 149, running loss: 0.446, current loss: 0.369, tau: 0.071: 100%|██████████| 61/61 [00:11<00:00,  5.45it/s]
# [Validation] Epoch: 149, running loss: 0.819, current loss: 1.388 tau: -0.031: 100%|██████████| 7/7 [00:00<00:00,  9.38it/s]
# [Training] Epoch: 150, running loss: 0.445, current loss: 0.367, tau: 0.089: 100%|██████████| 61/61 [00:10<00:00,  5.66it/s]
# [Validation] Epoch: 150, running loss: 0.821, current loss: 1.399 tau: -0.024: 100%|██████████| 7/7 [00:00<00:00,  9.55it/s]
# [Training] Epoch: 151, running loss: 0.444, current loss: 0.365, tau: 0.034: 100%|██████████| 61/61 [00:10<00:00,  5.70it/s]
# [Validation] Epoch: 151, running loss: 0.824, current loss: 1.407 tau: -0.008: 100%|██████████| 7/7 [00:00<00:00,  9.74it/s]
# [Training] Epoch: 152, running loss: 0.444, current loss: 0.368, tau: 0.030: 100%|██████████| 61/61 [00:10<00:00,  5.64it/s]
# [Validation] Epoch: 152, running loss: 0.814, current loss: 1.349 tau: -0.033: 100%|██████████| 7/7 [00:00<00:00,  9.60it/s]
# [Training] Epoch: 153, running loss: 0.444, current loss: 0.364, tau: 0.080: 100%|██████████| 61/61 [00:10<00:00,  5.71it/s]
# [Validation] Epoch: 153, running loss: 0.825, current loss: 1.419 tau: 0.005: 100%|██████████| 7/7 [00:00<00:00,  9.70it/s]
# [Training] Epoch: 154, running loss: 0.443, current loss: 0.366, tau: 0.010: 100%|██████████| 61/61 [00:11<00:00,  5.53it/s]
# [Validation] Epoch: 154, running loss: 0.826, current loss: 1.415 tau: -0.014: 100%|██████████| 7/7 [00:00<00:00,  8.13it/s]
# [Training] Epoch: 155, running loss: 0.443, current loss: 0.365, tau: 0.072: 100%|██████████| 61/61 [00:11<00:00,  5.46it/s]
# [Validation] Epoch: 155, running loss: 0.824, current loss: 1.412 tau: -0.024: 100%|██████████| 7/7 [00:00<00:00,  9.44it/s]
# [Training] Epoch: 156, running loss: 0.442, current loss: 0.363, tau: 0.101: 100%|██████████| 61/61 [00:10<00:00,  5.71it/s]
# [Validation] Epoch: 156, running loss: 0.826, current loss: 1.421 tau: -0.029: 100%|██████████| 7/7 [00:00<00:00,  9.58it/s]
# [Training] Epoch: 157, running loss: 0.442, current loss: 0.365, tau: 0.103: 100%|██████████| 61/61 [00:10<00:00,  5.67it/s]
# [Validation] Epoch: 157, running loss: 0.815, current loss: 1.335 tau: -0.029: 100%|██████████| 7/7 [00:00<00:00,  9.79it/s]
# [Training] Epoch: 158, running loss: 0.441, current loss: 0.362, tau: 0.064: 100%|██████████| 61/61 [00:10<00:00,  5.69it/s]
# [Validation] Epoch: 158, running loss: 0.829, current loss: 1.433 tau: -0.019: 100%|██████████| 7/7 [00:00<00:00,  9.44it/s]
# [Training] Epoch: 159, running loss: 0.441, current loss: 0.364, tau: 0.054: 100%|██████████| 61/61 [00:10<00:00,  5.70it/s]
# [Validation] Epoch: 159, running loss: 0.824, current loss: 1.421 tau: -0.002: 100%|██████████| 7/7 [00:00<00:00,  9.71it/s]
# [Training] Epoch: 160, running loss: 0.440, current loss: 0.362, tau: 0.063: 100%|██████████| 61/61 [00:11<00:00,  5.49it/s]
# [Validation] Epoch: 160, running loss: 0.818, current loss: 1.359 tau: -0.026: 100%|██████████| 7/7 [00:00<00:00,  9.09it/s]
# [Training] Epoch: 161, running loss: 0.440, current loss: 0.362, tau: 0.051: 100%|██████████| 61/61 [00:10<00:00,  5.63it/s]
# [Validation] Epoch: 161, running loss: 0.829, current loss: 1.437 tau: -0.035: 100%|██████████| 7/7 [00:00<00:00,  9.74it/s]
# [Training] Epoch: 162, running loss: 0.439, current loss: 0.362, tau: 0.083: 100%|██████████| 61/61 [00:10<00:00,  5.70it/s]
# [Validation] Epoch: 162, running loss: 0.820, current loss: 1.373 tau: -0.026: 100%|██████████| 7/7 [00:00<00:00,  9.64it/s]
# [Training] Epoch: 163, running loss: 0.439, current loss: 0.361, tau: 0.065: 100%|██████████| 61/61 [00:10<00:00,  5.69it/s]
# [Validation] Epoch: 163, running loss: 0.824, current loss: 1.395 tau: -0.021: 100%|██████████| 7/7 [00:00<00:00,  9.57it/s]
# [Training] Epoch: 164, running loss: 0.439, current loss: 0.361, tau: 0.072: 100%|██████████| 61/61 [00:10<00:00,  5.68it/s]
# [Validation] Epoch: 164, running loss: 0.822, current loss: 1.380 tau: -0.036: 100%|██████████| 7/7 [00:00<00:00,  9.58it/s]
# [Training] Epoch: 165, running loss: 0.439, current loss: 0.361, tau: 0.061: 100%|██████████| 61/61 [00:10<00:00,  5.71it/s]
# [Validation] Epoch: 165, running loss: 0.822, current loss: 1.381 tau: -0.056: 100%|██████████| 7/7 [00:00<00:00,  9.58it/s]
# [Training] Epoch: 166, running loss: 0.438, current loss: 0.361, tau: 0.056: 100%|██████████| 61/61 [00:11<00:00,  5.49it/s]
# [Validation] Epoch: 166, running loss: 0.820, current loss: 1.372 tau: -0.036: 100%|██████████| 7/7 [00:00<00:00,  8.65it/s]
# [Training] Epoch: 167, running loss: 0.438, current loss: 0.360, tau: 0.072: 100%|██████████| 61/61 [00:11<00:00,  5.36it/s]
# [Validation] Epoch: 167, running loss: 0.823, current loss: 1.380 tau: -0.021: 100%|██████████| 7/7 [00:00<00:00,  8.99it/s]
# [Training] Epoch: 168, running loss: 0.438, current loss: 0.360, tau: 0.082: 100%|██████████| 61/61 [00:11<00:00,  5.54it/s]
# [Validation] Epoch: 168, running loss: 0.822, current loss: 1.374 tau: -0.047: 100%|██████████| 7/7 [00:00<00:00,  9.46it/s]
# [Training] Epoch: 169, running loss: 0.437, current loss: 0.360, tau: 0.080: 100%|██████████| 61/61 [00:10<00:00,  5.55it/s]
# [Validation] Epoch: 169, running loss: 0.822, current loss: 1.377 tau: -0.009: 100%|██████████| 7/7 [00:00<00:00,  9.25it/s]
# [Training] Epoch: 170, running loss: 0.437, current loss: 0.360, tau: 0.087: 100%|██████████| 61/61 [00:10<00:00,  5.65it/s]
# [Validation] Epoch: 170, running loss: 0.822, current loss: 1.376 tau: -0.015: 100%|██████████| 7/7 [00:00<00:00,  9.64it/s]
# [Training] Epoch: 171, running loss: 0.437, current loss: 0.359, tau: 0.038: 100%|██████████| 61/61 [00:10<00:00,  5.66it/s]
# [Validation] Epoch: 171, running loss: 0.823, current loss: 1.377 tau: -0.029: 100%|██████████| 7/7 [00:00<00:00,  9.59it/s]
# [Training] Epoch: 172, running loss: 0.437, current loss: 0.359, tau: 0.038: 100%|██████████| 61/61 [00:11<00:00,  5.50it/s]
# [Validation] Epoch: 172, running loss: 0.824, current loss: 1.386 tau: -0.019: 100%|██████████| 7/7 [00:00<00:00,  7.62it/s]
# [Training] Epoch: 173, running loss: 0.436, current loss: 0.359, tau: 0.048: 100%|██████████| 61/61 [00:10<00:00,  5.61it/s]
# [Validation] Epoch: 173, running loss: 0.823, current loss: 1.376 tau: -0.048: 100%|██████████| 7/7 [00:00<00:00,  9.73it/s]
# [Training] Epoch: 174, running loss: 0.436, current loss: 0.359, tau: 0.085: 100%|██████████| 61/61 [00:10<00:00,  5.69it/s]
# [Validation] Epoch: 174, running loss: 0.823, current loss: 1.382 tau: -0.015: 100%|██████████| 7/7 [00:00<00:00,  9.64it/s]
# [Training] Epoch: 175, running loss: 0.436, current loss: 0.359, tau: 0.052: 100%|██████████| 61/61 [00:10<00:00,  5.56it/s]
# [Validation] Epoch: 175, running loss: 0.823, current loss: 1.376 tau: -0.057: 100%|██████████| 7/7 [00:00<00:00,  9.55it/s]
# [Training] Epoch: 176, running loss: 0.436, current loss: 0.358, tau: 0.065: 100%|██████████| 61/61 [00:10<00:00,  5.73it/s]
# [Validation] Epoch: 176, running loss: 0.824, current loss: 1.382 tau: -0.050: 100%|██████████| 7/7 [00:00<00:00,  9.65it/s]
# [Training] Epoch: 177, running loss: 0.435, current loss: 0.358, tau: 0.085: 100%|██████████| 61/61 [00:10<00:00,  5.69it/s]
# [Validation] Epoch: 177, running loss: 0.824, current loss: 1.384 tau: -0.053: 100%|██████████| 7/7 [00:00<00:00,  9.42it/s]
# [Training] Epoch: 178, running loss: 0.435, current loss: 0.358, tau: 0.040: 100%|██████████| 61/61 [00:11<00:00,  5.43it/s]
# [Validation] Epoch: 178, running loss: 0.824, current loss: 1.381 tau: -0.052: 100%|██████████| 7/7 [00:00<00:00,  9.06it/s]
# [Training] Epoch: 179, running loss: 0.435, current loss: 0.358, tau: 0.070: 100%|██████████| 61/61 [00:10<00:00,  5.66it/s]
# [Validation] Epoch: 179, running loss: 0.824, current loss: 1.384 tau: -0.060: 100%|██████████| 7/7 [00:00<00:00,  9.40it/s]
# [Training] Epoch: 180, running loss: 0.435, current loss: 0.358, tau: 0.068: 100%|██████████| 61/61 [00:10<00:00,  5.68it/s]
# [Validation] Epoch: 180, running loss: 0.824, current loss: 1.382 tau: -0.040: 100%|██████████| 7/7 [00:00<00:00,  9.75it/s]
# [Training] Epoch: 181, running loss: 0.435, current loss: 0.358, tau: 0.069: 100%|██████████| 61/61 [00:10<00:00,  5.68it/s]
# [Validation] Epoch: 181, running loss: 0.825, current loss: 1.383 tau: -0.040: 100%|██████████| 7/7 [00:00<00:00,  9.51it/s]
# [Training] Epoch: 182, running loss: 0.435, current loss: 0.358, tau: 0.064: 100%|██████████| 61/61 [00:10<00:00,  5.71it/s]
# [Validation] Epoch: 182, running loss: 0.825, current loss: 1.384 tau: -0.056: 100%|██████████| 7/7 [00:00<00:00,  9.66it/s]
# [Training] Epoch: 183, running loss: 0.435, current loss: 0.358, tau: 0.059: 100%|██████████| 61/61 [00:10<00:00,  5.62it/s]
# [Validation] Epoch: 183, running loss: 0.824, current loss: 1.382 tau: -0.044: 100%|██████████| 7/7 [00:00<00:00,  9.46it/s]
# [Training] Epoch: 184, running loss: 0.435, current loss: 0.357, tau: 0.070: 100%|██████████| 61/61 [00:11<00:00,  5.40it/s]
# [Validation] Epoch: 184, running loss: 0.825, current loss: 1.383 tau: -0.032: 100%|██████████| 7/7 [00:00<00:00,  9.06it/s]
# [Training] Epoch: 185, running loss: 0.434, current loss: 0.357, tau: 0.081: 100%|██████████| 61/61 [00:10<00:00,  5.68it/s]
# [Validation] Epoch: 185, running loss: 0.825, current loss: 1.383 tau: -0.059: 100%|██████████| 7/7 [00:00<00:00,  9.29it/s]
# [Training] Epoch: 186, running loss: 0.434, current loss: 0.357, tau: 0.051: 100%|██████████| 61/61 [00:10<00:00,  5.70it/s]
# [Validation] Epoch: 186, running loss: 0.825, current loss: 1.384 tau: -0.040: 100%|██████████| 7/7 [00:00<00:00,  9.55it/s]
# [Training] Epoch: 187, running loss: 0.434, current loss: 0.357, tau: 0.062: 100%|██████████| 61/61 [00:10<00:00,  5.70it/s]
# [Validation] Epoch: 187, running loss: 0.825, current loss: 1.383 tau: -0.034: 100%|██████████| 7/7 [00:00<00:00,  9.73it/s]
# [Training] Epoch: 188, running loss: 0.434, current loss: 0.357, tau: 0.054: 100%|██████████| 61/61 [00:10<00:00,  5.69it/s]
# [Validation] Epoch: 188, running loss: 0.825, current loss: 1.383 tau: -0.075: 100%|██████████| 7/7 [00:00<00:00,  9.74it/s]
# [Training] Epoch: 189, running loss: 0.434, current loss: 0.357, tau: 0.059: 100%|██████████| 61/61 [00:10<00:00,  5.68it/s]
# [Validation] Epoch: 189, running loss: 0.825, current loss: 1.382 tau: -0.057: 100%|██████████| 7/7 [00:00<00:00,  9.58it/s]
# [Training] Epoch: 190, running loss: 0.434, current loss: 0.357, tau: 0.069: 100%|██████████| 61/61 [00:11<00:00,  5.42it/s]
# [Validation] Epoch: 190, running loss: 0.825, current loss: 1.382 tau: -0.037: 100%|██████████| 7/7 [00:00<00:00,  8.95it/s]
# [Training] Epoch: 191, running loss: 0.434, current loss: 0.357, tau: 0.058: 100%|██████████| 61/61 [00:10<00:00,  5.70it/s]
# [Validation] Epoch: 191, running loss: 0.825, current loss: 1.382 tau: -0.046: 100%|██████████| 7/7 [00:00<00:00,  9.66it/s]
# [Training] Epoch: 192, running loss: 0.434, current loss: 0.357, tau: 0.045: 100%|██████████| 61/61 [00:10<00:00,  5.69it/s]
# [Validation] Epoch: 192, running loss: 0.825, current loss: 1.381 tau: -0.041: 100%|██████████| 7/7 [00:00<00:00,  9.43it/s]
# [Training] Epoch: 193, running loss: 0.434, current loss: 0.357, tau: 0.046: 100%|██████████| 61/61 [00:10<00:00,  5.72it/s]
# [Validation] Epoch: 193, running loss: 0.825, current loss: 1.381 tau: -0.056: 100%|██████████| 7/7 [00:00<00:00,  9.80it/s]
# [Training] Epoch: 194, running loss: 0.434, current loss: 0.357, tau: 0.058: 100%|██████████| 61/61 [00:10<00:00,  5.68it/s]
# [Validation] Epoch: 194, running loss: 0.825, current loss: 1.381 tau: -0.047: 100%|██████████| 7/7 [00:00<00:00,  9.55it/s]
# [Training] Epoch: 195, running loss: 0.434, current loss: 0.357, tau: 0.062: 100%|██████████| 61/61 [00:10<00:00,  5.64it/s]
# [Validation] Epoch: 195, running loss: 0.825, current loss: 1.381 tau: -0.047: 100%|██████████| 7/7 [00:00<00:00,  9.57it/s]
# [Training] Epoch: 196, running loss: 0.434, current loss: 0.357, tau: 0.063: 100%|██████████| 61/61 [00:11<00:00,  5.16it/s]
# [Validation] Epoch: 196, running loss: 0.825, current loss: 1.381 tau: -0.047: 100%|██████████| 7/7 [00:00<00:00,  9.72it/s]
# [Training] Epoch: 197, running loss: 0.434, current loss: 0.357, tau: 0.061: 100%|██████████| 61/61 [00:10<00:00,  5.71it/s]
# [Validation] Epoch: 197, running loss: 0.825, current loss: 1.381 tau: -0.054: 100%|██████████| 7/7 [00:00<00:00,  9.54it/s]
# [Training] Epoch: 198, running loss: 0.434, current loss: 0.357, tau: 0.062: 100%|██████████| 61/61 [00:10<00:00,  5.59it/s]
# [Validation] Epoch: 198, running loss: 0.825, current loss: 1.381 tau: -0.052: 100%|██████████| 7/7 [00:00<00:00,  9.70it/s]
# [Training] Epoch: 199, running loss: 0.434, current loss: 0.357, tau: 0.062: 100%|██████████| 61/61 [00:10<00:00,  5.70it/s]
# [Validation] Epoch: 199, running loss: 0.825, current loss: 1.381 tau: -0.052: 100%|██████████| 7/7 [00:00<00:00,  9.55it/s]
# 100%|██████████| 8/8 [00:01<00:00,  5.00it/s]

# %%
sub
# Out:
#                                                     ID  \
# 0            tile:xla:d6f5f54247bd1e58a10b9e7062c636ab
# 1            tile:xla:e3a655daa38e34ec240df959b650ac16
# 2            tile:xla:f8c2c1a1098b2a361c26df668b286c87
# 3            tile:xla:4dd1716853ed46ee4e7d09ede1732de8
# 4            tile:xla:d0a69155b6340748c36724e4bfc34be3
# ..                                                 ...
# 889  layout:nlp:random:60880ed76de53f4d7a1b960b24f2...
# 890  layout:nlp:random:23559853d9702baaaacbb0c83fd3...
# 891  layout:nlp:random:f6c146fc5cf10be4f3accbaca989...
# 892  layout:nlp:random:32531d07a084b319dce484f53a4c...
# 893  layout:nlp:random:3a0c5517a87df8d82fd637b83298...
#
#                                             TopConfigs
# 0                                            0;1;2;3;4
# 1                                            0;1;2;3;4
# 2                                            0;1;2;3;4
# 3                                            0;1;2;3;4
# 4                                            0;1;2;3;4
# ..                                                 ...
# 889  836;645;623;270;356;219;457;647;742;320;112;79...
# 890  126;350;703;215;924;204;377;214;51;616;827;906...
# 891  634;846;158;726;667;911;334;749;487;827;352;89...
# 892  26;691;22;853;977;748;466;364;907;189;818;325;...
# 893  405;242;615;654;859;425;19;471;49;221;729;314;...
#
# [894 rows x 2 columns]

# %%
sub.to_csv('submission.csv',index=False)
